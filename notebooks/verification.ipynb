# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
hits = pd.read_csv("../data/hits.csv")
hits = hits.sort_values(by=['time'])
hits
# Out:
#         dom_id  pmt_id   pos_x    pos_y    pos_z  dir_x  dir_y  dir_z  tot  \
# 325995    1054   32658 -16.064  -76.599  112.441  0.000  0.955 -0.296   35
# 325997    1054   32671 -16.208  -76.707  112.611 -0.719  0.415  0.558   24
# 325992    1053   32639 -16.064  -76.624  122.011  0.000  0.830  0.558   12
# 325996    1054   32670 -16.064  -76.624  112.611  0.000  0.830  0.558   54
# 325998    1054   32664 -15.968  -76.625  112.559  0.478  0.827  0.296   47
# ...        ...     ...     ...      ...      ...    ...    ...    ...  ...
# 239871    2016   62496  88.433  -60.180   38.011  0.719 -0.415  0.558   23
# 239869    1953   60527  30.897  -58.959  121.841  0.000  0.955 -0.296   26
# 238077    1673   51848  61.686  101.731   47.241 -0.827  0.478 -0.296   25
# 238075    1566   48536  40.629   67.440   37.959  0.478  0.827  0.296   29
# 238076    1638   50751  30.952   86.327   37.731 -0.460  0.266 -0.847   29
#
#               time  label
# 325995     28449.0      1
# ...

# %% [markdown]
# # Load the data

# %%
slices = list(range(0, 10000000, 15000))

timeslices = []
while len(timeslices) < 10:
    choice = random.choice(slices)
    if choice < slices[-1]:
        timeslices.append((choice, choice+15000))

timeslices
# Out:
# [(9675000, 9690000),
#  (5835000, 5850000),
#  (9855000, 9870000),
#  (3825000, 3840000),
#  (6960000, 6975000),
#  (8715000, 8730000),
#  (8355000, 8370000),
#  (9855000, 9870000),
#  (9585000, 9600000),
#  (1170000, 1185000)]

# %%
fig, axs = plt.subplots(5, 2, figsize=(15, 15))

# plot 1
timeslices_idx = 0
slice = hits[(hits.time >= timeslices[timeslices_idx][0]) & (hits.time < timeslices[timeslices_idx][1])]
axs[0, 0].scatter(slice.time, slice.pos_x)
axs[0, 0].set_xlabel('Time (in ns)')
axs[0, 0].set_ylabel('Hits (pos x)')

# plot 2
timeslices_idx = 1
slice = hits[(hits.time >= timeslices[timeslices_idx][0]) & (hits.time < timeslices[timeslices_idx][1])]
axs[0, 1].scatter(slice.time, slice.pos_x)
axs[0, 1].set_xlabel('Time (in ns)')
axs[0, 1].set_ylabel('Hits (pos x)')

# plot 3
timeslices_idx = 2
slice = hits[(hits.time >= timeslices[timeslices_idx][0]) & (hits.time < timeslices[timeslices_idx][1])]
axs[1, 0].scatter(slice.time, slice.pos_x)
axs[1, 0].set_xlabel('Time (in ns)')
axs[1, 0].set_ylabel('Hits (pos x)')

# plot 4
timeslices_idx = 3
slice = hits[(hits.time >= timeslices[timeslices_idx][0]) & (hits.time < timeslices[timeslices_idx][1])]
axs[1, 1].scatter(slice.time, slice.pos_x)
axs[1, 1].set_xlabel('Time (in ns)')
axs[1, 1].set_ylabel('Hits (pos x)')

# plot 5
timeslices_idx = 4
slice = hits[(hits.time >= timeslices[timeslices_idx][0]) & (hits.time < timeslices[timeslices_idx][1])]
axs[2, 0].scatter(slice.time, slice.pos_x)
axs[2, 0].set_xlabel('Time (in ns)')
axs[2, 0].set_ylabel('Hits (pos x)')
    
# plot 6
timeslices_idx = 5
slice = hits[(hits.time >= timeslices[timeslices_idx][0]) & (hits.time < timeslices[timeslices_idx][1])]
axs[2, 1].scatter(slice.time, slice.pos_x)
axs[2, 1].set_xlabel('Time (in ns)')
axs[2, 1].set_ylabel('Hits (pos x)')

# plot 7
timeslices_idx = 6
slice = hits[(hits.time >= timeslices[timeslices_idx][0]) & (hits.time < timeslices[timeslices_idx][1])]
axs[3, 0].scatter(slice.time, slice.pos_x)
axs[3, 0].set_xlabel('Time (in ns)')
axs[3, 0].set_ylabel('Hits (pos x)')

# plot 8
timeslices_idx = 7
slice = hits[(hits.time >= timeslices[timeslices_idx][0]) & (hits.time < timeslices[timeslices_idx][1])]
axs[3, 1].scatter(slice.time, slice.pos_x)
axs[3, 1].set_xlabel('Time (in ns)')
axs[3, 1].set_ylabel('Hits (pos x)')

# plot 9
timeslices_idx = 8
slice = hits[(hits.time >= timeslices[timeslices_idx][0]) & (hits.time < timeslices[timeslices_idx][1])]
axs[4, 0].scatter(slice.time, slice.pos_x)
axs[4, 0].set_xlabel('Time (in ns)')
axs[4, 0].set_ylabel('Hits (pos x)')

# plot 10
timeslices_idx = 9
slice = hits[(hits.time >= timeslices[timeslices_idx][0]) & (hits.time < timeslices[timeslices_idx][1])]
axs[4, 1].scatter(slice.time, slice.pos_x)
axs[4, 1].set_xlabel('Time (in ns)')
axs[4, 1].set_ylabel('Hits (pos x)')

plt.suptitle("Scatter Plots of Randomly Selected Hits Within Timeslices of 15 ns", fontsize=16)

plt.savefig('../assets/hits_random.png')

# %% [markdown]
# The concern was that time for hits had to be ofsetted to avoid a certain pattern showing up. To identify such a problem, random timeslices of 15000ns were taken and plotted for the x values. The plots show no specific pattern which then indicates no need for offset.
