# %% [markdown]
# # Combine the Energy Info with Hits DF
#
# 1. Read HD5 files
# 2. Files are: `mc_info` and `mc_hits`
# 3. Combine `energy` from `mc_info` with `mc_hits`
# 4. Save new hits df
#
# ## Combining Energy with Hits
# The combination is based on index positions in `mc_hits`.

# %%
import pandas as pd
import numpy as np
import matplotlib

# %%
raw_events_path = '../../data/raw/events.h5'

# %%
event_info = pd.read_hdf(raw_events_path, key='/data/mc_info')
event_hits =  pd.read_hdf(raw_events_path, key='/data/mc_hits')

# %%
event_info.head(20)
# Out:
#       nu_E  type  nu_dir.x  nu.dir.y  nu.dir.z  nu.pos.x  nu.pos.y  nu.pos.z  \
# 0   15.540   -14 -0.630831  0.436518  0.641486   -85.337   154.304    35.735
# 1   11.458    14  0.070157  0.942066 -0.328009    19.081   169.073   -92.435
# 2   11.485    14  0.367514  0.049922 -0.928677   -61.314   130.036   -64.078
# 3   11.571    14 -0.177418  0.344584  0.921838    48.457    76.398   112.710
# 4   13.148   -14 -0.997387  0.065683  0.030071   138.488  -166.544    52.433
# 5   91.444    14 -0.155981 -0.027443  0.987379   170.351   112.860  -171.454
# 6   25.020   -14 -0.222299  0.871988 -0.436142   -29.961  -139.823   -39.763
# 7   14.765   -14 -0.454631 -0.145056 -0.878789   212.293    -7.850   172.990
# 8   70.096   -14 -0.574247  0.152260 -0.804399    10.753  -177.158    52.685
# 9   29.825    14  0.930999 -0.362261 -0.044802    85.201   146.340  -105.288
# 10  21.925    14 -0.368715  0.179268 -0.912092   -18.310   -42.036   101.394
# 11  37.496   -14  0.199512  0.977630  0.066590    53.366    -4.879    97.109
# 12  52.175    14  0.942359 -0.075629 -0.325943    14.450  -132.213   -17.443
# 13  24.964    14  0.437464 -0.779812 -0.447794  -184.220   -42.419    64.364
# 14  60.814   -14 -0.085085  0.544501 -0.834433    48.889     5.915   -69.022
# 15  31.869    14 -0.365321  0.224982 -0.903285   182.068    38.926   -81.150
# 16  30.956    14  0.339311  0.716115  0.609956    81.484    20.199     7.594
# 17  27.960    14  0.843949 -0.522774 -0.120239    51.773   -50.108   -11.096
# 18  98.616   -14 -0.483620  0.798625 -0.358204   249.231  -242.840    41.359
# 19  14.566   -14  0.229842  0.620128 -0.750076   -77.414   128.181     5.151
#
#     nu.hits.start  nu.hits.end
# 0               0            5
# 1               5            6
# 2               6           11
# 3              11           15
# 4              15           17
# 5              17           34
# 6              34          259
# 7             259          259
# 8             259          290
# 9             290          291
# 10            291          391
# 11            391          433
# 12            433          500
# 13            500          504
# 14            504          554
# 15            554          558
# 16            558          700
# 17            700          944
# 18            944          982
# 19            982          985

# %%
event_hits.head()
# Out:
#    h.dom_id  h.pmt_id  h.pos.x  h.pos.y  h.pos.z  h.dir.x  h.dir.y  h.dir.z  \
# 0        40      1231  -55.897  101.800  169.059   -0.478    0.827    0.296
# 1        93      2879  -26.344   86.850  178.511    0.000    0.830    0.558
# 2       187      5769  -74.918   65.363  139.831    0.000    0.531   -0.847
# 3       196      6071  -74.774   65.340   56.111    0.719    0.415    0.558
# 4       221      6842  -65.186   50.797  160.359   -0.478    0.827    0.296
#
#    h.tot         h.t
# 0     28  27286567.0
# 1     27  27287009.0
# 2     25  27289060.0
# 3     30  27287235.0
# 4     27  27286697.0

# %%
event_info.nu_E.min()
# Out:
# 10.002

# %%
event_hits = event_hits.rename_axis('pos').reset_index()
event_hits['energy'] =''

# %%
event_hits
# Out:
#            pos  h.dom_id  h.pmt_id  h.pos.x  h.pos.y  h.pos.z  h.dir.x  \
# 0            0        40      1231  -55.897  101.800  169.059   -0.478
# 1            1        93      2879  -26.344   86.850  178.511    0.000
# 2            2       187      5769  -74.918   65.363  139.831    0.000
# 3            3       196      6071  -74.774   65.340   56.111    0.719
# 4            4       221      6842  -65.186   50.797  160.359   -0.478
# ...        ...       ...       ...      ...      ...      ...      ...
# 489901  489901      1934     59941   77.988  -40.148  130.541    0.000
# 489902  489902      1981     61393   70.237  -59.962  196.389    0.415
# 489903  489903      1995     61845   70.298  -59.901   65.511    0.719
# 489904  489904      2012     62366   88.385  -60.262   74.159    0.478
# 489905  489905      2022     62670   40.429  -77.199  150.841    0.827
#
#         h.dir.y  h.dir.z  h.tot         h.t energy
# 0         0.827    0.296     28  27286567.0
# 1         0.830    0.558     27  27287009.0
# 2         0.531   -0.847     25  27289060.0
# 3         0.415    0.558     30  27287235.0
# 4         0.827    0.296     27  27286697.0
# ...         ...      ...    ...         ...    ...
# 489901   -0.955   -0.296     18  72056356.0
# 489902   -0.720   -0.556     29  72056427.0
# 489903   -0.415    0.558     25  72056374.0
# 489904   -0.827    0.296     24  72056345.0
# 489905   -0.478   -0.296     26  72056403.0
#
# [489906 rows x 12 columns]

# %%
pd.Series(list(range(0, 1000000000, 15000)))
# Out:
# 0                0
# 1            15000
# 2            30000
# 3            45000
# 4            60000
#            ...
# 66662    999930000
# 66663    999945000
# 66664    999960000
# 66665    999975000
# 66666    999990000
# Length: 66667, dtype: int64

# %%
event_info['event_range'] = list(event_info['nu.hits.start']
# Out:
# nu_E             False
# type             False
# nu_dir.x         False
# nu.dir.y         False
# nu.dir.z         False
# nu.pos.x         False
# nu.pos.y         False
# nu.pos.z         False
# nu.hits.start    False
# nu.hits.end      False
# event_range      False
# dtype: bool

# %%
event_info['event_range'] = event_info['nu.hits.start'].apply(lambda x: [x]) + event_info['nu.hits.end'].apply(lambda x: [x])

# %%
event_info
# Out:
#         nu_E  type  nu_dir.x  nu.dir.y  nu.dir.z  nu.pos.x  nu.pos.y  \
# 0     15.540   -14 -0.630831  0.436518  0.641486   -85.337   154.304
# 1     11.458    14  0.070157  0.942066 -0.328009    19.081   169.073
# 2     11.485    14  0.367514  0.049922 -0.928677   -61.314   130.036
# 3     11.571    14 -0.177418  0.344584  0.921838    48.457    76.398
# 4     13.148   -14 -0.997387  0.065683  0.030071   138.488  -166.544
# ...      ...   ...       ...       ...       ...       ...       ...
# 5730  73.038   -14 -0.119695 -0.113570 -0.986294  -102.301    10.814
# 5731  79.484    14 -0.220923  0.896138 -0.384876    51.252    56.680
# 5732  35.602    14 -0.665612  0.267922  0.696548   191.109   -60.389
# 5733  10.022    14  0.868500 -0.195664  0.455438  -126.753    61.647
# 5734  49.086    14 -0.253683  0.713673  0.652928   166.667  -212.045
#
#       nu.pos.z  nu.hits.start  nu.hits.end       event_range
# 0       35.735              0            5            [0, 5]
# 1      -92.435              5            6            [5, 6]
# 2      -64.078              6           11           [6, 11]
# 3      112.710             11           15          [11, 15]
# 4       52.433             15           17          [15, 17]
# ...        ...            ...          ...               ...
# 5730   259.625         489453       489455  [489453, 489455]
# 5731    72.604         489455       489817  [489455, 489817]
# 5732    -7.956         489817       489820  [489817, 489820]
# 5733   -71.618         489820       489897  [489820, 489897]
# 5734   -68.294         489897       489906  [489897, 489906]
#
# [5735 rows x 11 columns]

# %%
event_hits['energy'] = event_hits.loc[event_hits['pos'].isin(range(0,5)), ]

# %%
event_hits
# Out:
#            pos  h.dom_id  h.pmt_id  h.pos.x  h.pos.y  h.pos.z  h.dir.x  \
# 0            0        40      1231  -55.897  101.800  169.059   -0.478
# 1            1        93      2879  -26.344   86.850  178.511    0.000
# 2            2       187      5769  -74.918   65.363  139.831    0.000
# 3            3       196      6071  -74.774   65.340   56.111    0.719
# 4            4       221      6842  -65.186   50.797  160.359   -0.478
# ...        ...       ...       ...      ...      ...      ...      ...
# 489901  489901      1934     59941   77.988  -40.148  130.541    0.000
# 489902  489902      1981     61393   70.237  -59.962  196.389    0.415
# 489903  489903      1995     61845   70.298  -59.901   65.511    0.719
# 489904  489904      2012     62366   88.385  -60.262   74.159    0.478
# 489905  489905      2022     62670   40.429  -77.199  150.841    0.827
#
#         h.dir.y  h.dir.z  h.tot         h.t energy
# 0         0.827    0.296     28  27286567.0      0
# 1         0.830    0.558     27  27287009.0      1
# 2         0.531   -0.847     25  27289060.0      2
# 3         0.415    0.558     30  27287235.0      3
# 4         0.827    0.296     27  27286697.0      4
# ...         ...      ...    ...         ...    ...
# 489901   -0.955   -0.296     18  72056356.0    NaN
# 489902   -0.720   -0.556     29  72056427.0    NaN
# 489903   -0.415    0.558     25  72056374.0    NaN
# 489904   -0.827    0.296     24  72056345.0    NaN
# 489905   -0.478   -0.296     26  72056403.0    NaN
#
# [489906 rows x 12 columns]

# %%
event_info.head()
# Out:
#      nu_E  type  nu_dir.x  nu.dir.y  nu.dir.z  nu.pos.x  nu.pos.y  nu.pos.z  \
# 0  15.540   -14 -0.630831  0.436518  0.641486   -85.337   154.304    35.735
# 1  11.458    14  0.070157  0.942066 -0.328009    19.081   169.073   -92.435
# 2  11.485    14  0.367514  0.049922 -0.928677   -61.314   130.036   -64.078
# 3  11.571    14 -0.177418  0.344584  0.921838    48.457    76.398   112.710
# 4  13.148   -14 -0.997387  0.065683  0.030071   138.488  -166.544    52.433
#
#    nu.hits.start  nu.hits.end event_range
# 0              0            5      [0, 5]
# 1              5            6      [5, 6]
# 2              6           11     [6, 11]
# 3             11           15    [11, 15]
# 4             15           17    [15, 17]

# %%
df = pd.DataFrame()

for idx, row in event_info.iterrows():
#     print("{0} \n  {1}".format(idx, row))
    slice = event_hits.iloc[row['nu.hits.start']: row['nu.hits.end']]
#     print(slice)
    slice['energy'] = row['nu_E']
    print(slice)
    df = pd.concat([df, slice])
    break
# Out:
#    pos  h.dom_id  h.pmt_id  h.pos.x  h.pos.y  h.pos.z  h.dir.x  h.dir.y  \
# 0    0        40      1231  -55.897  101.800  169.059   -0.478    0.827
# 1    1        93      2879  -26.344   86.850  178.511    0.000    0.830
# 2    2       187      5769  -74.918   65.363  139.831    0.000    0.531
# 3    3       196      6071  -74.774   65.340   56.111    0.719    0.415
# 4    4       221      6842  -65.186   50.797  160.359   -0.478    0.827
#
#    h.dir.z  h.tot         h.t  energy
# 0    0.296     28  27286567.0   15.54
# 1    0.558     27  27287009.0   15.54
# 2   -0.847     25  27289060.0   15.54
# 3    0.558     30  27287235.0   15.54
# 4    0.296     27  27286697.0   15.54
# /Users/shrutirao/Documents/Coding/Thesis/km3net/venv/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
df
# Out:
#    pos  h.dom_id  h.pmt_id  h.pos.x  h.pos.y  h.pos.z  h.dir.x  h.dir.y  \
# 0    0        40      1231  -55.897  101.800  169.059   -0.478    0.827
# 1    1        93      2879  -26.344   86.850  178.511    0.000    0.830
# 2    2       187      5769  -74.918   65.363  139.831    0.000    0.531
# 3    3       196      6071  -74.774   65.340   56.111    0.719    0.415
# 4    4       221      6842  -65.186   50.797  160.359   -0.478    0.827
#
#    h.dir.z  h.tot         h.t  energy
# 0    0.296     28  27286567.0   15.54
# 1    0.558     27  27287009.0   15.54
# 2   -0.847     25  27289060.0   15.54
# 3    0.558     30  27287235.0   15.54
# 4    0.296     27  27286697.0   15.54

# %%
for i in event_info[['nu_E', 'event_range']].values:
    print(i[0])
    slice = event_hits.loc[event_hits['pos'].isin(range(0,5))]
    slice['energy'] = 15.5
    print(slicea)
#     print(event_hits.head())
    break
# Out:
# 15.54
#    pos  h.dom_id  h.pmt_id  h.pos.x  h.pos.y  h.pos.z  h.dir.x  h.dir.y  \
# 0    0        40      1231  -55.897  101.800  169.059   -0.478    0.827
# 1    1        93      2879  -26.344   86.850  178.511    0.000    0.830
# 2    2       187      5769  -74.918   65.363  139.831    0.000    0.531
# 3    3       196      6071  -74.774   65.340   56.111    0.719    0.415
# 4    4       221      6842  -65.186   50.797  160.359   -0.478    0.827
#
#    h.dir.z  h.tot         h.t  energy
# 0    0.296     28  27286567.0    15.5
# 1    0.558     27  27287009.0    15.5
# 2   -0.847     25  27289060.0    15.5
# 3    0.558     30  27287235.0    15.5
# 4    0.296     27  27286697.0    15.5
# /Users/shrutirao/Documents/Coding/Thesis/km3net/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
data = zip(event_info['nu.hits.start'],
           event_info['nu.hits.end'],
           event_info['nu_E'])
a
for a, b, c in data:
    event_hits['energy'] = np.where(event_hits.pos.between(a, b, inclusive=True), c, "Unfilled")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-85-5b506f2ebe4f> in <module>
#       4
#       5 for a, b, c in data:
# ----> 6     event_hits['energy'] = np.where(event_hits.pos.between(a, b, inclusive=True), c, "Unfilled")
#       7
#
# ~/Documents/Coding/Thesis/km3net/venv/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# ~/Documents/Coding/Thesis/km3net/venv/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2999         self._ensure_valid_index(value)
#    3000         value = self._sanitize_column(key, value)
# -> 3001         NDFrame._set_item(self, key, value)
#    3002
#    3003         # check if we are modifying a copy
#
# ~/Documents/Coding/Thesis/km3net/venv/lib/python3.7/site-packages/pandas/core/generic.py in _set_item(self, key, value)
#    3622
#    3623     def _set_item(self, key, value) -> None:
# -> 3624         self._data.set(key, value)
#    3625         self._clear_item_cache()
#    3626
#
# ~/Documents/Coding/Thesis/km3net/venv/lib/python3.7/site-packages/pandas/core/internals/managers.py in set(self, item, value)
#    1088             blk_locs = blklocs[val_locs.indexer]
#    1089             if blk.should_store(value):
# -> 1090                 blk.set(blk_locs, value_getitem(val_locs))
#    1091             else:
#    1092                 unfit_mgr_locs.append(blk.mgr_locs.as_array[blk_locs])
#
# ~/Documents/Coding/Thesis/km3net/venv/lib/python3.7/site-packages/pandas/core/internals/blocks.py in set(self, locs, values)
#     374         None
#     375         """
# --> 376         self.values[locs] = values
#     377
#     378     def delete(self, loc):
#
# KeyboardInterrupt:
