# %% [markdown]
# # Preprocessing Pipeline
#
# 1. 77231331 function calls (71330714 primitive calls) in 337.452 seconds
# 2. 61537967 function calls (55739951 primitive calls) in 79.316 seconds
# 3. 3489,556 in 840.342 seconds
# 4. 32768 function calls (32026 primitive calls) in 0.176 seconds

# %%
def preprocessing_pipeline():
    """
    Run all the required preprocessing files
    """
    # %run 1.0_xyt_data_preparation.ipynb
    # %run 2.0_mesh_preprocessing.ipynb
    # %run 3.0_mesh_generation.ipynb
    # %run 4.0_train_test_split.ipynb

# %%
import cProfile
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import re

cProfile.run('preprocessing_pipeline()')

# %%
vals = [337.452*3, 79.316*3, 840.342*3, 0.176*3]
pipe = ["3D Coordinates", "Feature Engineering", "Mesh Generation", "Train/Test Split"]

sns.lineplot(pipe, vals, linestyle='--', marker='o', color='b')
plt.ylabel("Execution Time (in seconds)")
plt.savefig("../../assets/execution_time.pdf", bbox_inches="tight")

# %%
sum(vals)
# Out:
# 6793.836
