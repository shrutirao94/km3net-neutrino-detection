# %% [markdown]
# # Prepare Data for Train-Test

# %%
def housekeeping(files):
    """
    Checks and removes unwanted files or folders
    1. .ipynb_checkpoints/
    2. .DS_Store
    3. train/
    4. test/
    """
    
    if ".ipynb_checkpoints" in files:
        print("Removing .ipynb_checkpoints...")
        shutil.rmtree(path + ".ipynb_checkpoints")
    else:
        print("No action taken")
        
    if ".DS_Store" in files:
        os.remove(path + ".DS_Store")
    else:
        print("No action taken")
        
    if 'train' or 'test' in files:
        return
#         try:
#             shutil.rmtree(path + 'train')
#         except OSError as e:
#             print ("Note: %s - %s." % (e.filename, e.strerror))
#         try:
#             shutil.rmtree(path + 'test')
#         except OSError as e:
#             print ("Note: %s - %s." % (e.filename, e.strerror))
    
    return


def randomize_files(files):
    """
    Shuffles files in a random order
    """
    return shuffle(files)


def prepare_split(files):
    """
    Identifies the ratios for files to be split into
    
    **Note**
    Current setting is for 80-20
    """
    eighty = int(0.8 * len(files))
    twenty = int(len(files) - eighty)
    files = np.array(files)
    
    return eighty, twenty, files


def generate_ids(eighty, twenty):
    """
    Assigns 1 to 80% of the files and 0 to 20% of the files
    """
    idx = np.hstack((np.ones(eighty),
                     np.zeros(twenty)))
    return idx


def train_test_split(files, idx):
    """
    Files tagged as 1 are categorised as training files
    Files tagged as 0 are categorised as test files
    """
    train = files[idx == 1]
    test = files[idx == 0]
    print("TRAIN SET: {0}".format(train))
    print("TEST SET: {0}".format(test))
    return train, test


def save_mixed_files():
    """
    Saves all mixed groups in the respective train and test folders
    """
    dir_mixed_paths = [PATH_MIXED + "train/", PATH_MIXED + "test/"]

    for paths, category in zip(dir_mixed_paths, categories):
        if not os.path.exists(paths):
            os.makedirs(paths)
        
        if os.path.exists(paths):
            for file in category:
                file_path = PATH_MIXED + file
                print(f'file_path: {file_path}')
                shutil.move(file_path, paths)
                
                
def save_noise_files():
    """
    Saves all noise files in its respective train and test folders
    """
    dir_noise_paths = [PATH_NOISE + "train/", PATH_NOISE + "test/"]

    for paths, category in zip(dir_noise_paths, categories):
        if not os.path.exists(paths):
            os.makedirs(paths)

        if os.path.exists(paths):
            for noise_file in category:
                file_path = PATH_NOISE + noise_file
                print(f'file_path: {file_path}')
                shutil.move(file_path, paths)

# %%
import pandas as pd
import numpy as np
import os
import random
from random import shuffle
import shutil

PATH_MIXED = "../../../data/unsampled/xzt/processed_points/mixed/"
PATH_NOISE = "../../../data/unsampled/xzt/processed_points/noise/"

dir_paths = [PATH_MIXED, PATH_NOISE]
save_types = [save_mixed_files, save_noise_files]


for path, types in zip(dir_paths, save_types):
    print("Working on {}".format(path))
    
    # Cleanup unwanted files/folders    
    files = os.listdir(path)
    
    housekeeping(files)
    
#     # First: Randomize data 
#     housekeeping(files)
    randomize_files(files)
    
#     # Calculate Split
    eighty, twenty, files = prepare_split(files)

#     # Generate 1s and 0s as IDs
    idx = generate_ids(eighty, twenty)

#     # Split data 
    train, test = train_test_split(files, idx) 
#     housekeeping(files)
    categories = [train, test]
    types()
# Out:
# Working on ../../../data/unsampled/xzt/processed_points/mixed/
# No action taken
# No action taken
# TRAIN SET: ['group_4532.xyz' 'group_857.xyz' 'group_2338.xyz' 'group_4243.xyz'
#  'group_5795.xyz' 'group_2759.xyz' 'group_4679.xyz' 'group_4741.xyz'
#  'group_4562.xyz' 'group_691.xyz' 'group_809.xyz' 'group_6378.xyz'
#  'group_355.xyz' 'group_281.xyz' 'group_3094.xyz' 'group_1658.xyz'
#  'group_1038.xyz' 'group_394.xyz' 'group_4460.xyz' 'group_5116.xyz'
#  'group_2211.xyz' 'group_1141.xyz' 'group_6038.xyz' 'group_2367.xyz'
#  'group_3025.xyz' 'group_2731.xyz' 'group_1825.xyz' 'group_607.xyz'
#  'group_6553.xyz' 'group_5815.xyz' 'group_6564.xyz' 'group_6534.xyz'
#  'group_5857.xyz' 'group_5866.xyz' 'group_1488.xyz' 'group_440.xyz'
#  'group_5000.xyz' 'group_615.xyz' 'group_3923.xyz' 'group_2185.xyz'
#  'group_554.xyz' 'group_1454.xyz' 'group_4417.xyz' 'group_3727.xyz'
#  'group_3514.xyz' 'group_5010.xyz' 'group_4735.xyz' 'group_3063.xyz'
#  'group_1618.xyz' 'group_2517.xyz' 'group_6084.xyz' 'group_1172.xyz'
#  'group_6314.xyz' 'group_6134.xyz' 'group_6470.xyz' 'group_639.xyz'
#  'group_1184.xyz' 'group_1516.xyz' 'group_4215.xyz' 'group_5823.xyz'
#  'group_5621.xyz' 'group_979.xyz' 'group_3084.xyz' 'group_1637.xyz'
#  'group_716.xyz' 'group_3845.xyz' 'group_5211.xyz' 'group_3611.xyz'
#  'group_2024.xyz' 'group_4793.xyz' 'group_5114.xyz' 'group_3778.xyz'
#  'group_5886.xyz' 'group_3252.xyz' 'group_4958.xyz' 'group_32.xyz'
#  'group_530.xyz' 'group_1496.xyz' 'group_5931.xyz' 'group_2795.xyz'
#  'group_3700.xyz' 'group_1599.xyz' 'group_1209.xyz' 'group_1887.xyz'
#  'group_2711.xyz' 'group_4104.xyz' 'group_584.xyz' 'group_797.xyz'
#  'group_4926.xyz' 'group_1275.xyz' 'group_6542.xyz' 'group_4227.xyz'
#  'group_3670.xyz' 'group_5133.xyz' 'group_231.xyz' 'group_4327.xyz'
#  'group_2362.xyz' 'group_3001.xyz' 'group_2374.xyz' 'group_103.xyz'
#  'group_2293.xyz' 'group_3490.xyz' 'group_375.xyz' 'group_1918.xyz'
#  'group_1813.xyz' 'group_3953.xyz' 'group_4301.xyz' 'group_477.xyz'
#  'group_6054.xyz' 'group_1973.xyz' 'group_2323.xyz' 'group_5234.xyz'
#  'group_55.xyz' 'group_5030.xyz' 'group_6530.xyz' 'group_6588.xyz'
#  'group_5422.xyz' 'group_1344.xyz' 'group_3483.xyz' 'group_3740.xyz'
#  'group_6006.xyz' 'group_1653.xyz' 'group_5032.xyz' 'group_4336.xyz'
#  'group_5725.xyz' 'group_4646.xyz' 'group_4282.xyz' 'group_3967.xyz'
#  'group_2654.xyz' 'group_2567.xyz' 'group_3287.xyz' 'group_5215.xyz'
#  'group_2389.xyz' 'group_50.xyz' 'group_3570.xyz' 'group_4023.xyz'
#  'group_5812.xyz' 'group_2231.xyz' 'group_6495.xyz' 'group_5295.xyz'
#  'group_2330.xyz' 'group_2447.xyz' 'group_4565.xyz' 'group_4515.xyz'
#  'group_3398.xyz' 'group_5799.xyz' 'group_1163.xyz' 'group_1446.xyz'
#  'group_1584.xyz' 'group_2098.xyz' 'group_1194.xyz' 'group_1732.xyz'
#  'group_4943.xyz' 'group_810.xyz' 'group_1232.xyz' 'group_6221.xyz'
#  'group_4347.xyz' 'group_1276.xyz' 'group_5659.xyz' 'group_1650.xyz']
# TEST SET: ['group_988.xyz' 'group_5883.xyz' 'group_1441.xyz' 'group_4783.xyz'
#  'group_4717.xyz' 'group_2821.xyz' 'group_6493.xyz' 'group_2021.xyz'
#  'group_2587.xyz' 'group_5222.xyz' 'group_4274.xyz' 'group_4799.xyz'
#  'group_4775.xyz' 'group_758.xyz' 'group_909.xyz' 'group_1189.xyz'
#  'group_6433.xyz' 'group_6427.xyz' 'group_3960.xyz' 'group_532.xyz'
#  'group_4615.xyz' 'group_1729.xyz' 'group_3416.xyz' 'group_4444.xyz'
#  'group_4430.xyz' 'group_437.xyz' 'group_1481.xyz' 'group_2872.xyz'
#  'group_3168.xyz' 'group_3925.xyz' 'group_5550.xyz' 'group_3792.xyz'
#  'group_5941.xyz' 'group_4060.xyz' 'group_5009.xyz' 'group_3189.xyz'
#  'group_3222.xyz' 'group_4426.xyz' 'group_3340.xyz' 'group_5840.xyz'
#  'group_4019.xyz' 'group_3507.xyz' 'group_6181.xyz' 'group_3799.xyz'
#  'group_4267.xyz' 'group_4870.xyz' 'group_210.xyz' 'group_2557.xyz'
#  'group_3763.xyz' 'group_5648.xyz' 'group_990.xyz' 'group_474.xyz'
#  'group_208.xyz' 'group_1391.xyz' 'group_6241.xyz' 'group_4591.xyz'
#  'group_1101.xyz' 'group_1246.xyz' 'group_5006.xyz' 'group_1583.xyz'
#  'group_5701.xyz' 'group_5511.xyz' 'group_669.xyz' 'group_5991.xyz'
#  'group_2385.xyz' 'group_4647.xyz' 'group_6589.xyz' 'group_5412.xyz'
#  'group_3815.xyz' 'group_5190.xyz' 'group_3219.xyz' 'group_3123.xyz'
#  'group_6396.xyz' 'group_2956.xyz' 'group_3352.xyz' 'group_432.xyz'
#  'group_416.xyz' 'group_4571.xyz' 'group_2932.xyz' 'group_1405.xyz'
#  'group_5605.xyz' 'group_3042.xyz' 'group_3355.xyz' 'group_583.xyz'
#  'group_1346.xyz' 'group_1667.xyz' 'group_3758.xyz' 'group_5182.xyz'
#  'group_1304.xyz' 'group_1202.xyz' 'group_4328.xyz' 'group_301.xyz'
#  'group_6333.xyz' 'group_4391.xyz' 'group_903.xyz' 'group_1151.xyz'
#  'group_2934.xyz' 'group_6630.xyz' 'group_2834.xyz' 'group_2414.xyz'
#  'group_4848.xyz' 'group_6177.xyz' 'group_4179.xyz' 'group_3974.xyz'
#  'group_630.xyz' 'group_2527.xyz' 'group_2093.xyz' 'group_5982.xyz'
#  'group_3180.xyz' 'group_2621.xyz' 'group_3943.xyz' 'group_4900.xyz'
#  'group_3215.xyz' 'group_1413.xyz' 'group_5097.xyz' 'group_3609.xyz'
#  'group_4032.xyz' 'group_686.xyz' 'group_5922.xyz' 'group_1204.xyz'
#  'group_6132.xyz' 'group_1325.xyz' 'group_5103.xyz' 'group_134.xyz'
#  'group_449.xyz' 'group_4640.xyz' 'group_4199.xyz' 'group_1374.xyz']
# TEST SET: ['group_1586.xyz' 'group_5718.xyz' 'group_6555.xyz' 'group_6560.xyz'
#  'group_2197.xyz' 'group_1846.xyz' 'group_3152.xyz' 'group_6048.xyz'
#  'group_3253.xyz' 'group_2533.xyz' 'group_3492.xyz' 'group_4874.xyz'
#  'group_5491.xyz' 'group_3569.xyz' 'group_1016.xyz' 'group_914.xyz'
#  'group_5308.xyz' 'group_2128.xyz' 'group_5434.xyz' 'group_5337.xyz'
#  'group_4796.xyz' 'group_1681.xyz' 'group_788.xyz' 'group_1639.xyz'
#  'group_2751.xyz' 'group_1955.xyz' 'group_999.xyz' 'group_1129.xyz'
#  'group_762.xyz' 'group_5578.xyz' 'group_5510.xyz' 'group_3487.xyz'
#  'group_5678.xyz' 'group_2869.xyz' 'group_648.xyz' 'group_6432.xyz'
#  'group_601.xyz' 'group_1333.xyz' 'group_4969.xyz' 'group_6540.xyz']
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_2658.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4671.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3704.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4897.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_6139.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4695.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5067.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_190.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_2719.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3941.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4463.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3594.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4477.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4483.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1531.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3403.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3968.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1108.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5149.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_2957.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3440.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_2272.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_2875.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1055.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3060.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_347.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_6117.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_6436.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5977.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_374.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3985.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_0.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4590.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5905.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_576.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5038.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1567.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4081.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4989.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1620.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_2587.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5222.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4274.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4799.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4775.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_758.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_909.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1189.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_6433.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_6427.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3960.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_532.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4615.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1729.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3416.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4444.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4430.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_437.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1481.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_2872.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3168.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3925.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5550.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3792.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5941.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4060.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5009.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3189.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3222.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4426.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3340.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5840.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4019.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3507.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_6181.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3799.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4267.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4870.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_210.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_2557.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3763.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5648.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_990.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_474.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_208.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1391.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_6241.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4591.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1101.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1246.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5006.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1583.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5701.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5511.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_669.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5991.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_2385.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4647.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_6589.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5412.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3815.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5190.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3219.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3123.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_6396.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_2956.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3352.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_432.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_416.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4571.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_2932.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1405.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5605.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3042.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3355.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_583.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1346.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1667.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3758.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5182.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1304.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1202.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4328.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_301.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_6333.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4391.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_903.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1151.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_2934.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_6630.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_2834.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_2414.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4848.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_6177.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4179.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3974.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_630.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_2527.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_2093.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5982.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3180.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_2621.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3943.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4900.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3215.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1413.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5097.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3609.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4032.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_686.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5922.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1204.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_6132.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1325.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5103.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_134.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_449.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4640.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4199.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1374.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1586.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5718.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_6555.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_6560.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_2197.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1846.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3152.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_6048.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3253.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_2533.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3492.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4874.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5491.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3569.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1016.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_914.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5308.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_2128.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5434.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5337.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4796.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1681.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_788.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1639.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_2751.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1955.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_999.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1129.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_762.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5578.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5510.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_3487.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_5678.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_2869.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_648.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_6432.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_601.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_1333.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_4969.xyz
# file_path: ../../../data/unsampled/xzt/processed_points/noise/group_6540.xyz

# %%
import os

# %%
import open3d as o3d
folder = "../../../data/unsampled/xyt/meshes/noise/train/"

# %%
avg_points = []
avg_triangles = []

for file in os.listdir(folder):
    mesh = o3d.io.read_triangle_mesh(folder+file)
    avg_points += [len(mesh.vertices)]
    avg_triangles += [len(mesh.triangles)]

# %%
sum(avg_points)/len(avg_points)
# avg_triangles

# %%
sum(avg_triangles)/len(avg_triangles)

# %%
mesh = o3d.io.read_triangle_mesh(folder+"group_1101_mesh.off")
mesh
# Out:
# geometry::TriangleMesh with 5137 points and 8247 triangles.

# %%
def check_properties(mesh):
    mesh.compute_vertex_normals()

    edge_manifold = mesh.is_edge_manifold(allow_boundary_edges=True)
    edge_manifold_boundary = mesh.is_edge_manifold(allow_boundary_edges=False)
    vertex_manifold = mesh.is_vertex_manifold()
    self_intersecting = mesh.is_self_intersecting()
    watertight = mesh.is_watertight()
    orientable = mesh.is_orientable()
    print("Mesh Properties for Event Groups (Training Data): \n")
    print(f"  vertex_manifold:        {vertex_manifold}")
    print(f"  self_intersecting:      {self_intersecting}")
    print(f"  watertight:             {watertight}")
    print(f"  orientable:             {orientable}")

# %%
check_properties(mesh)
# Out:
# Mesh Properties for Event Groups (Training Data):
#
#   vertex_manifold:        False
#   self_intersecting:      True
#   watertight:             False
#   orientable:             False
