# %% [markdown]
# # Prepare Data for Train-Test

# %%
def housekeeping(files):
    """
    Checks and removes unwanted files or folders
    1. .ipynb_checkpoints/
    2. .DS_Store
    3. train/
    4. test/
    """
    
    if ".ipynb_checkpoints" in files:
        print("Removing .ipynb_checkpoints...")
        shutil.rmtree(path + ".ipynb_checkpoints")
    else:
        print("No action taken")
        
    if ".DS_Store" in files:
        os.remove(path + ".DS_Store")
    else:
        print("No action taken")
        
    if 'train' or 'test' in files:
        try:
            shutil.rmtree(path + 'train')
        except OSError as e:
            print ("Note: %s - %s." % (e.filename, e.strerror))
        try:
            shutil.rmtree(path + 'test')
        except OSError as e:
            print ("Note: %s - %s." % (e.filename, e.strerror))
    
    return


def randomize_files(files):
    """
    Shuffles files in a random order
    """
    return shuffle(files)


def prepare_split(files):
    """
    Identifies the ratios for files to be split into
    
    **Note**
    Current setting is for 80-20
    """
    eighty = int(0.8 * len(files))
    twenty = int(len(files) - eighty)
    files = np.array(files)
    
    return eighty, twenty, files


def generate_ids(eighty, twenty):
    """
    Assigns 1 to 80% of the files and 0 to 20% of the files
    """
    idx = np.hstack((np.ones(eighty),
                     np.zeros(twenty)))
    return idx


def train_test_split(files, idx):
    """
    Files tagged as 1 are categorised as training files
    Files tagged as 0 are categorised as test files
    """
    train = files[idx == 1]
    test = files[idx == 0]
    print("TRAIN SET: {0}".format(train))
    print("TEST SET: {0}".format(test))
    return train, test


def save_mixed_files():
    """
    Saves all mixed groups in the respective train and test folders
    """
    dir_mixed_paths = [PATH_MIXED + "train/", PATH_MIXED + "test/"]

    for paths, category in zip(dir_mixed_paths, categories):
        if not os.path.exists(paths):
            os.makedirs(paths)
        
        if os.path.exists(paths):
            for file in category:
                file_path = PATH_MIXED + file
                print(f'file_path: {file_path}')
                shutil.move(file_path, paths)
                
                
def save_noise_files():
    """
    Saves all noise files in its respective train and test folders
    """
    dir_noise_paths = [PATH_NOISE + "train/", PATH_NOISE + "test/"]

    for paths, category in zip(dir_noise_paths, categories):
        if not os.path.exists(paths):
            os.makedirs(paths)

        if os.path.exists(paths):
            for noise_file in category:
                file_path = PATH_NOISE + noise_file
                print(f'file_path: {file_path}')
                shutil.move(file_path, paths)

# %%
import pandas as pd
import numpy as np
import os
import random
from random import shuffle
import shutil

PATH_MIXED = "../../../data/test/xyt/meshes/mixed/"
PATH_NOISE = "../../../data/test/xyt/meshes/noise/"

dir_paths = [PATH_MIXED, PATH_NOISE]
save_types = [save_mixed_files, save_noise_files]


for path, types in zip(dir_paths, save_types):
    print("Working on {}".format(path))
    
    # Cleanup unwanted files/folders    
    files = os.listdir(path)
    housekeeping(files)
    print (files)
    
    # First: Randomize data 
    randomize_files(files)
    
    # Calculate Split
    eighty, twenty, files = prepare_split(files)

    # Generate 1s and 0s as IDs
    idx = generate_ids(eighty, twenty)

    # Split data 
    train, test = train_test_split(files, idx) 
    categories = [train, test]
    types()
# Out:
# Working on ../../../data/test/xyt/meshes/mixed/
# No action taken
# No action taken
# Note: ../../../data/test/xyt/meshes/mixed/train - No such file or directory.
# Note: ../../../data/test/xyt/meshes/mixed/test - No such file or directory.
# ['group_2795_mesh.off', 'group_32_mesh.off', 'group_6493_mesh.off', 'group_941_mesh.off', 'group_1918_mesh.off', 'group_491_mesh.off', 'group_3514_mesh.off', 'group_4620_mesh.off', 'group_1357_mesh.off', 'group_2098_mesh.off', 'group_1038_mesh.off', 'group_4243_mesh.off', 'group_4717_mesh.off', 'group_2517_mesh.off', 'group_3310_mesh.off', 'group_2211_mesh.off', 'group_3670_mesh.off', 'group_3778_mesh.off', 'group_440_mesh.off', 'group_4336_mesh.off', 'group_1637_mesh.off', 'group_1825_mesh.off', 'group_3923_mesh.off', 'group_3212_mesh.off', 'group_1172_mesh.off', 'group_4532_mesh.off', 'group_2759_mesh.off', 'group_1496_mesh.off', 'group_5030_mesh.off', 'group_4104_mesh.off', 'group_1276_mesh.off', 'group_2711_mesh.off', 'group_554_mesh.off', 'group_4793_mesh.off', 'group_6134_mesh.off', 'group_3727_mesh.off', 'group_1446_mesh.off', 'group_5215_mesh.off', 'group_103_mesh.off', 'group_4735_mesh.off', 'group_5133_mesh.off', 'group_584_mesh.off', 'group_1973_mesh.off', 'group_4926_mesh.off', 'group_3611_mesh.off', 'group_469_mesh.off', 'group_5812_mesh.off', 'group_3063_mesh.off', 'group_2330_mesh.off', 'group_1599_mesh.off', 'group_810_mesh.off', 'group_4854_mesh.off', 'group_5422_mesh.off', 'group_2024_mesh.off', 'group_4679_mesh.off', 'group_55_mesh.off', 'group_4034_mesh.off', 'group_5857_mesh.off', 'group_2447_mesh.off', 'group_691_mesh.off', 'group_2374_mesh.off', 'group_4646_mesh.off', 'group_6221_mesh.off', 'group_4327_mesh.off', 'group_5747_mesh.off', 'group_5281_mesh.off', 'group_1441_mesh.off', 'group_1232_mesh.off', 'group_2293_mesh.off', 'group_5815_mesh.off', 'group_4282_mesh.off', 'group_1618_mesh.off', 'group_5886_mesh.off', 'group_6564_mesh.off', 'group_1163_mesh.off', 'group_3398_mesh.off', 'group_1650_mesh.off', 'group_6495_mesh.off', 'group_1732_mesh.off', 'group_2567_mesh.off', 'group_1141_mesh.off', 'group_5976_mesh.off', 'group_6530_mesh.off', 'group_615_mesh.off', 'group_3967_mesh.off', 'group_979_mesh.off', 'group_2362_mesh.off', 'group_249_mesh.off', 'group_4783_mesh.off', 'group_3170_mesh.off', 'group_4023_mesh.off', 'group_6470_mesh.off', 'group_5116_mesh.off', 'group_1584_mesh.off', 'group_3483_mesh.off', 'group_997_mesh.off', 'group_1516_mesh.off', 'group_5659_mesh.off', 'group_3953_mesh.off', 'group_375_mesh.off', 'group_3740_mesh.off', 'group_3924_mesh.off', 'group_3287_mesh.off', 'group_4347_mesh.off', 'group_716_mesh.off', 'group_857_mesh.off', 'group_3084_mesh.off', 'group_3490_mesh.off', 'group_5799_mesh.off', 'group_5866_mesh.off', 'group_4741_mesh.off', 'group_5883_mesh.off', 'group_4215_mesh.off', 'group_797_mesh.off', 'group_1209_mesh.off', 'group_4958_mesh.off', 'group_5032_mesh.off', 'group_6109_mesh.off', 'group_1275_mesh.off', 'group_639_mesh.off', 'group_2021_mesh.off', 'group_281_mesh.off', 'group_2231_mesh.off', 'group_4565_mesh.off', 'group_2338_mesh.off', 'group_50_mesh.off', 'group_607_mesh.off', 'group_2185_mesh.off', 'group_4080_mesh.off', 'group_2389_mesh.off', 'group_1488_mesh.off', 'group_231_mesh.off', 'group_809_mesh.off', 'group_6054_mesh.off', 'group_1194_mesh.off', 'group_5931_mesh.off', 'group_3001_mesh.off', 'group_5010_mesh.off', 'group_394_mesh.off', 'group_2731_mesh.off', 'group_5151_mesh.off', 'group_6378_mesh.off', 'group_6084_mesh.off', 'group_2821_mesh.off', 'group_6542_mesh.off', 'group_1813_mesh.off', 'group_2367_mesh.off', 'group_3252_mesh.off', 'group_4301_mesh.off', 'group_5234_mesh.off', 'group_477_mesh.off', 'group_6534_mesh.off', 'group_5621_mesh.off', 'group_1214_mesh.off', 'group_4943_mesh.off', 'group_1454_mesh.off', 'group_5295_mesh.off', 'group_3094_mesh.off', 'group_2323_mesh.off', 'group_5725_mesh.off', 'group_5270_mesh.off', 'group_1869_mesh.off', 'group_787_mesh.off', 'group_6337_mesh.off', 'group_1484_mesh.off', 'group_1887_mesh.off', 'group_1671_mesh.off', 'group_3700_mesh.off', 'group_530_mesh.off', 'group_5114_mesh.off', 'group_1184_mesh.off', 'group_5211_mesh.off', 'group_4417_mesh.off', 'group_1764_mesh.off', 'group_4428_mesh.off', 'group ...
# TRAIN SET: ['group_5281_mesh.off' 'group_5295_mesh.off' 'group_3398_mesh.off'
#  'group_3700_mesh.off' 'group_1813_mesh.off' 'group_375_mesh.off'
#  'group_1276_mesh.off' 'group_3483_mesh.off' 'group_4023_mesh.off'
#  'group_6567_mesh.off' 'group_1836_mesh.off' 'group_3001_mesh.off'
#  'group_3670_mesh.off' 'group_5747_mesh.off' 'group_32_mesh.off'
#  'group_2567_mesh.off' 'group_5795_mesh.off' 'group_584_mesh.off'
#  'group_5116_mesh.off' 'group_5886_mesh.off' 'group_1671_mesh.off'
#  'group_4735_mesh.off' 'group_6378_mesh.off' 'group_2323_mesh.off'
#  'group_4783_mesh.off' 'group_5010_mesh.off' 'group_3967_mesh.off'
#  'group_1653_mesh.off' 'group_477_mesh.off' 'group_2185_mesh.off'
#  'group_4417_mesh.off' 'group_4565_mesh.off' 'group_4532_mesh.off'
#  'group_1973_mesh.off' 'group_2021_mesh.off' 'group_3570_mesh.off'
#  'group_5883_mesh.off' 'group_3727_mesh.off' 'group_2330_mesh.off'
#  'group_6553_mesh.off' 'group_4347_mesh.off' 'group_1764_mesh.off'
#  'group_5815_mesh.off' 'group_5931_mesh.off' 'group_787_mesh.off'
#  'group_2338_mesh.off' 'group_469_mesh.off' 'group_5030_mesh.off'
#  'group_857_mesh.off' 'group_979_mesh.off' 'group_1214_mesh.off'
#  'group_1618_mesh.off' 'group_5312_mesh.off' 'group_4958_mesh.off'
#  'group_6588_mesh.off' 'group_5976_mesh.off' 'group_281_mesh.off'
#  'group_4215_mesh.off' 'group_2654_mesh.off' 'group_3063_mesh.off'
#  'group_50_mesh.off' 'group_4562_mesh.off' 'group_1488_mesh.off'
#  'group_6493_mesh.off' 'group_1825_mesh.off' 'group_1232_mesh.off'
#  'group_3778_mesh.off' 'group_1357_mesh.off' 'group_440_mesh.off'
#  'group_2711_mesh.off' 'group_6038_mesh.off' 'group_3084_mesh.off'
#  'group_5857_mesh.off' 'group_5032_mesh.off' 'group_3025_mesh.off'
#  'group_5000_mesh.off' 'group_2374_mesh.off' 'group_6470_mesh.off'
#  'group_2821_mesh.off' 'group_4620_mesh.off' 'group_2098_mesh.off'
#  'group_6006_mesh.off' 'group_6530_mesh.off' 'group_1454_mesh.off'
#  'group_2231_mesh.off' 'group_1163_mesh.off' 'group_530_mesh.off'
#  'group_4336_mesh.off' 'group_3923_mesh.off' 'group_1446_mesh.off'
#  'group_4104_mesh.off' 'group_941_mesh.off' 'group_3490_mesh.off'
#  'group_6221_mesh.off' 'group_1496_mesh.off' 'group_4080_mesh.off'
#  'group_1441_mesh.off' 'group_5211_mesh.off' 'group_1141_mesh.off'
#  'group_4428_mesh.off' 'group_639_mesh.off' 'group_6109_mesh.off'
#  'group_5799_mesh.off' 'group_2795_mesh.off' 'group_1184_mesh.off'
#  'group_4646_mesh.off' 'group_797_mesh.off' 'group_6134_mesh.off'
#  'group_4327_mesh.off' 'group_1918_mesh.off' 'group_5114_mesh.off'
#  'group_1484_mesh.off' 'group_809_mesh.off' 'group_4034_mesh.off'
#  'group_4460_mesh.off' 'group_5621_mesh.off' 'group_3845_mesh.off'
#  'group_4943_mesh.off' 'group_5215_mesh.off' 'group_4717_mesh.off'
#  'group_5866_mesh.off' 'group_5659_mesh.off' 'group_2211_mesh.off'
#  'group_4741_mesh.off' 'group_615_mesh.off' 'group_4926_mesh.off'
#  'group_1194_mesh.off' 'group_691_mesh.off' 'group_2447_mesh.off'
#  'group_3212_mesh.off' 'group_6564_mesh.off' 'group_4515_mesh.off'
#  'group_1275_mesh.off' 'group_3094_mesh.off' 'group_103_mesh.off'
#  'group_1584_mesh.off' 'group_3310_mesh.off' 'group_2293_mesh.off'
#  'group_55_mesh.off' 'group_997_mesh.off' 'group_3611_mesh.off'
#  'group_1637_mesh.off' 'group_1650_mesh.off' 'group_3170_mesh.off'
#  'group_491_mesh.off' 'group_6084_mesh.off' 'group_2024_mesh.off'
#  'group_355_mesh.off' 'group_6314_mesh.off' 'group_2389_mesh.off'
#  'group_5133_mesh.off' 'group_4793_mesh.off' 'group_5823_mesh.off'
#  'group_249_mesh.off' 'group_5234_mesh.off' 'group_6495_mesh.off'
#  'group_4243_mesh.off' 'group_4301_mesh.off' 'group_6054_mesh.off'
#  'group_1209_mesh.off']
# TEST SET: ['group_3514_mesh.off' 'group_2731_mesh.off' 'group_5151_mesh.off'
#  'group_1172_mesh.off' 'group_1344_mesh.off' 'group_2362_mesh.off'
#  'group_1516_mesh.off' 'group_1869_mesh.off' 'group_2759_mesh.off'
#  'group_3287_mesh.off' 'group_4679_mesh.off' 'group_1273_mesh.off'
#  'group_3924_mesh.off' 'group_4282_mesh.off' 'group_3252_mesh.off'
#  'group_988_mesh.off' 'group_810_mesh.off' 'group_394_mesh.off'
#  'group_231_mesh.off' 'group_607_mesh.off' 'group_5270_mesh.off'
#  'group_716_mesh.off' 'group_4227_mesh.off' 'group_1599_mesh.off'
#  'group_1038_mesh.off' 'group_1658_mesh.off' 'group_6337_mesh.off'
#  'group_6542_mesh.off' 'group_6534_mesh.off' 'group_5725_mesh.off'
#  'group_5812_mesh.off' 'group_1887_mesh.off' 'group_2517_mesh.off'
#  'group_1732_mesh.off' 'group_554_mesh.off' 'group_4854_mesh.off'
#  'group_5422_mesh.off' 'group_3953_mesh.off' 'group_2367_mesh.off'
#  'group_3740_mesh.off']
# file_path: ../../../data/test/xyt/meshes/mixed/group_5281_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5295_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3398_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3700_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1813_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_375_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1276_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3483_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4023_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_6567_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1836_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3001_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3670_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5747_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_32_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_2567_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5795_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_584_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5116_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5886_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1671_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4735_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_6378_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_2323_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4783_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5010_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3967_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1653_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_477_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_2185_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4417_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4565_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4532_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1973_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_2021_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3570_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5883_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3727_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_2330_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_6553_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4347_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1764_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5815_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5931_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_787_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_2338_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_469_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5030_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_857_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_979_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1214_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1618_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5312_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4958_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_6588_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5976_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_281_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4215_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_2654_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3063_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_50_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4562_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1488_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_6493_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1825_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1232_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3778_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1357_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_440_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_2711_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_6038_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3084_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5857_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5032_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3025_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5000_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_2374_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_6470_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_2821_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4620_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_2098_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_6006_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_6530_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1454_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_2231_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1163_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_530_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4336_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3923_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1446_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4104_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_941_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3490_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_6221_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1496_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4080_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1441_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5211_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1141_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4428_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_639_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_6109_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5799_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_2795_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1184_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4646_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_797_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_6134_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4327_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1918_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5114_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1484_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_809_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4034_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4460_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5621_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3845_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4943_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5215_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4717_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5866_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5659_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_2211_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4741_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_615_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4926_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1194_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_691_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_2447_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3212_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_6564_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4515_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1275_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3094_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_103_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1584_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3310_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_2293_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_55_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_997_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3611_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1637_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1650_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3170_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_491_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_6084_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_2024_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_355_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_6314_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_2389_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5133_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4793_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5823_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_249_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5234_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_6495_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4243_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4301_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_6054_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1209_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3514_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_2731_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5151_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1172_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1344_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_2362_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1516_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1869_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_2759_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3287_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4679_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1273_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3924_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4282_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3252_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_988_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_810_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_394_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_231_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_607_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5270_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_716_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4227_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1599_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1038_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1658_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_6337_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_6542_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_6534_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5725_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5812_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1887_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_2517_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_1732_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_554_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_4854_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_5422_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3953_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_2367_mesh.off
# file_path: ../../../data/test/xyt/meshes/mixed/group_3740_mesh.off
# Working on ../../../data/test/xyt/meshes/noise/
# No action taken
# No action taken
# Note: ../../../data/test/xyt/meshes/noise/train - No such file or directory.
# Note: ../../../data/test/xyt/meshes/noise/test - No such file or directory.
# ['group_270_mesh.off', 'group_271_mesh.off', 'group_239_mesh.off', 'group_157_mesh.off', 'group_330_mesh.off', 'group_474_mesh.off', 'group_346_mesh.off', 'group_347_mesh.off', 'group_44_mesh.off', 'group_169_mesh.off', 'group_168_mesh.off', 'group_409_mesh.off', 'group_232_mesh.off', 'group_114_mesh.off', 'group_373_mesh.off', 'group_39_mesh.off', 'group_437_mesh.off', 'group_436_mesh.off', 'group_304_mesh.off', 'group_397_mesh.off', 'group_396_mesh.off', 'group_95_mesh.off', 'group_245_mesh.off', 'group_415_mesh.off', 'group_141_mesh.off', 'group_109_mesh.off', 'group_282_mesh.off', 'group_210_mesh.off', 'group_463_mesh.off', 'group_462_mesh.off', 'group_89_mesh.off', 'group_137_mesh.off', 'group_259_mesh.off', 'group_258_mesh.off', 'group_190_mesh.off', 'group_457_mesh.off', 'group_456_mesh.off', 'group_365_mesh.off', 'group_364_mesh.off', 'group_224_mesh.off', 'group_67_mesh.off', 'group_10_mesh.off', 'group_252_mesh.off', 'group_82_mesh.off', 'group_381_mesh.off', 'group_58_mesh.off', 'group_420_mesh.off', 'group_421_mesh.off', 'group_174_mesh.off', 'group_313_mesh.off', 'group_228_mesh.off', 'group_216_mesh.off', 'group_54_mesh.off', 'group_178_mesh.off', 'group_285_mesh.off', 'group_284_mesh.off', 'group_464_mesh.off', 'group_465_mesh.off', 'group_356_mesh.off', 'group_131_mesh.off', 'group_450_mesh.off', 'group_104_mesh.off', 'group_363_mesh.off', 'group_196_mesh.off', 'group_84_mesh.off', 'group_254_mesh.off', 'group_17_mesh.off', 'group_173_mesh.off', 'group_315_mesh.off', 'group_314_mesh.off', 'group_172_mesh.off', 'group_387_mesh.off', 'group_119_mesh.off', 'group_0_mesh.off', 'group_405_mesh.off', 'group_336_mesh.off', 'group_151_mesh.off', 'group_98_mesh.off', 'group_473_mesh.off', 'group_127_mesh.off', 'group_126_mesh.off', 'group_309_mesh.off', 'group_293_mesh.off', 'group_42_mesh.off', 'group_234_mesh.off', 'group_77_mesh.off', 'group_446_mesh.off', 'group_112_mesh.off', 'group_374_mesh.off', 'group_48_mesh.off', 'group_302_mesh.off', 'group_303_mesh.off', 'group_165_mesh.off', 'group_243_mesh.off', 'group_93_mesh.off', 'group_479_mesh.off', 'group_193_mesh.off', 'group_100_mesh.off', 'group_366_mesh.off', 'group_367_mesh.off', 'group_65_mesh.off', 'group_227_mesh.off', 'group_149_mesh.off', 'group_148_mesh.off', 'group_250_mesh.off', 'group_251_mesh.off', 'group_80_mesh.off', 'group_218_mesh.off', 'group_383_mesh.off', 'group_382_mesh.off', 'group_177_mesh.off', 'group_423_mesh.off', 'group_325_mesh.off', 'group_143_mesh.off', 'group_324_mesh.off', 'group_417_mesh.off', 'group_416_mesh.off', 'group_485_mesh.off', 'group_198_mesh.off', 'group_199_mesh.off', 'group_265_mesh.off', 'group_429_mesh.off', 'group_213_mesh.off', 'group_212_mesh.off', 'group_134_mesh.off', 'group_352_mesh.off', 'group_353_mesh.off', 'group_460_mesh.off', 'group_461_mesh.off', 'group_19_mesh.off', 'group_338_mesh.off', 'group_339_mesh.off', 'group_370_mesh.off', 'group_116_mesh.off', 'group_278_mesh.off', 'group_160_mesh.off', 'group_307_mesh.off', 'group_96_mesh.off', 'group_4_mesh.off', 'group_273_mesh.off', 'group_31_mesh.off', 'group_30_mesh.off', 'group_449_mesh.off', 'group_448_mesh.off', 'group_332_mesh.off', 'group_155_mesh.off', 'group_400_mesh.off', 'group_123_mesh.off', 'group_345_mesh.off', 'group_122_mesh.off', 'group_46_mesh.off', 'group_47_mesh.off', 'group_237_mesh.off', 'group_159_mesh.off', 'group_8_mesh.off', 'group_183_mesh.off', 'group_376_mesh.off', 'group_110_mesh.off', 'group_377_mesh.off', 'group_208_mesh.off', 'group_301_mesh.off', 'group_300_mesh.off', 'group_432_mesh.off', 'group_241_mesh.off', 'group_91_mesh.off', 'group_3_mesh.off', 'group_189_mesh.off', 'group_153_mesh.off', 'group_335_mesh.off', 'group_407_mesh.off', 'group_342_mesh.off', 'group_439_mesh.off', 'group_291_mesh.off', 'group_399_mesh.off', 'group_41_mesh.off', 'group_361_mesh.off', 'group_106_mesh.off', 'group_194_mesh.off', 'group_328_mesh.off', 'group_62_mesh.off', 'group_220_mesh.off', 'group_63_mesh.off', 'group_87_mesh.off', 'group_256 ...
# TRAIN SET: ['group_479_mesh.off' 'group_265_mesh.off' 'group_245_mesh.off'
#  'group_278_mesh.off' 'group_77_mesh.off' 'group_119_mesh.off'
#  'group_183_mesh.off' 'group_474_mesh.off' 'group_354_mesh.off'
#  'group_252_mesh.off' 'group_189_mesh.off' 'group_328_mesh.off'
#  'group_258_mesh.off' 'group_462_mesh.off' 'group_473_mesh.off'
#  'group_148_mesh.off' 'group_291_mesh.off' 'group_420_mesh.off'
#  'group_159_mesh.off' 'group_293_mesh.off' 'group_42_mesh.off'
#  'group_251_mesh.off' 'group_220_mesh.off' 'group_373_mesh.off'
#  'group_347_mesh.off' 'group_385_mesh.off' 'group_134_mesh.off'
#  'group_151_mesh.off' 'group_91_mesh.off' 'group_112_mesh.off'
#  'group_301_mesh.off' 'group_30_mesh.off' 'group_381_mesh.off'
#  'group_80_mesh.off' 'group_224_mesh.off' 'group_456_mesh.off'
#  'group_153_mesh.off' 'group_314_mesh.off' 'group_67_mesh.off'
#  'group_196_mesh.off' 'group_133_mesh.off' 'group_155_mesh.off'
#  'group_137_mesh.off' 'group_376_mesh.off' 'group_407_mesh.off'
#  'group_365_mesh.off' 'group_87_mesh.off' 'group_8_mesh.off'
#  'group_383_mesh.off' 'group_396_mesh.off' 'group_218_mesh.off'
#  'group_439_mesh.off' 'group_210_mesh.off' 'group_332_mesh.off'
#  'group_417_mesh.off' 'group_109_mesh.off' 'group_367_mesh.off'
#  'group_63_mesh.off' 'group_364_mesh.off' 'group_21_mesh.off'
#  'group_463_mesh.off' 'group_14_mesh.off' 'group_199_mesh.off'
#  'group_285_mesh.off' 'group_330_mesh.off' 'group_254_mesh.off'
#  'group_0_mesh.off' 'group_457_mesh.off' 'group_353_mesh.off'
#  'group_382_mesh.off' 'group_143_mesh.off' 'group_429_mesh.off'
#  'group_106_mesh.off' 'group_173_mesh.off' 'group_213_mesh.off'
#  'group_448_mesh.off' 'group_39_mesh.off' 'group_304_mesh.off'
#  'group_48_mesh.off' 'group_123_mesh.off' 'group_190_mesh.off'
#  'group_446_mesh.off' 'group_165_mesh.off' 'group_208_mesh.off'
#  'group_116_mesh.off' 'group_239_mesh.off' 'group_405_mesh.off'
#  'group_54_mesh.off' 'group_160_mesh.off' 'group_198_mesh.off'
#  'group_416_mesh.off' 'group_58_mesh.off' 'group_62_mesh.off'
#  'group_361_mesh.off' 'group_286_mesh.off' 'group_485_mesh.off'
#  'group_424_mesh.off' 'group_234_mesh.off' 'group_168_mesh.off'
#  'group_216_mesh.off' 'group_110_mesh.off' 'group_273_mesh.off'
#  'group_313_mesh.off' 'group_141_mesh.off' 'group_4_mesh.off'
#  'group_44_mesh.off' 'group_342_mesh.off' 'group_93_mesh.off'
#  'group_169_mesh.off' 'group_84_mesh.off' 'group_464_mesh.off'
#  'group_397_mesh.off' 'group_127_mesh.off' 'group_262_mesh.off'
#  'group_324_mesh.off' 'group_387_mesh.off' 'group_212_mesh.off'
#  'group_157_mesh.off' 'group_409_mesh.off' 'group_237_mesh.off'
#  'group_432_mesh.off' 'group_317_mesh.off' 'group_172_mesh.off'
#  'group_96_mesh.off' 'group_170_mesh.off' 'group_17_mesh.off'
#  'group_465_mesh.off' 'group_338_mesh.off' 'group_3_mesh.off'
#  'group_363_mesh.off' 'group_482_mesh.off' 'group_467_mesh.off'
#  'group_325_mesh.off' 'group_228_mesh.off' 'group_126_mesh.off'
#  'group_241_mesh.off' 'group_400_mesh.off' 'group_415_mesh.off'
#  'group_31_mesh.off' 'group_437_mesh.off' 'group_65_mesh.off'
#  'group_178_mesh.off' 'group_227_mesh.off' 'group_82_mesh.off'
#  'group_370_mesh.off' 'group_232_mesh.off' 'group_89_mesh.off'
#  'group_46_mesh.off' 'group_315_mesh.off' 'group_366_mesh.off'
#  'group_461_mesh.off' 'group_144_mesh.off' 'group_284_mesh.off'
#  'group_352_mesh.off' 'group_95_mesh.off' 'group_335_mesh.off'
#  'group_122_mesh.off' 'group_100_mesh.off' 'group_374_mesh.off'
#  'group_259_mesh.off']
# TEST SET: ['group_300_mesh.off' 'group_356_mesh.off' 'group_215_mesh.off'
#  'group_282_mesh.off' 'group_336_mesh.off' 'group_131_mesh.off'
#  'group_270_mesh.off' 'group_309_mesh.off' 'group_250_mesh.off'
#  'group_460_mesh.off' 'group_19_mesh.off' 'group_69_mesh.off'
#  'group_450_mesh.off' 'group_114_mesh.off' 'group_436_mesh.off'
#  'group_177_mesh.off' 'group_104_mesh.off' 'group_302_mesh.off'
#  'group_399_mesh.off' 'group_449_mesh.off' 'group_193_mesh.off'
#  'group_423_mesh.off' 'group_377_mesh.off' 'group_194_mesh.off'
#  'group_339_mesh.off' 'group_346_mesh.off' 'group_243_mesh.off'
#  'group_384_mesh.off' 'group_47_mesh.off' 'group_345_mesh.off'
#  'group_149_mesh.off' 'group_303_mesh.off' 'group_98_mesh.off'
#  'group_307_mesh.off' 'group_41_mesh.off' 'group_421_mesh.off'
#  'group_256_mesh.off' 'group_174_mesh.off' 'group_271_mesh.off'
#  'group_10_mesh.off']
# file_path: ../../../data/test/xyt/meshes/noise/group_479_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_265_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_245_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_278_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_77_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_119_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_183_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_474_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_354_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_252_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_189_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_328_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_258_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_462_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_473_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_148_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_291_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_420_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_159_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_293_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_42_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_251_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_220_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_373_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_347_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_385_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_134_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_151_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_91_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_112_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_301_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_30_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_381_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_80_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_224_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_456_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_153_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_314_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_67_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_196_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_133_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_155_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_137_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_376_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_407_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_365_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_87_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_8_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_383_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_396_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_218_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_439_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_210_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_332_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_417_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_109_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_367_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_63_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_364_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_21_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_463_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_14_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_199_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_285_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_330_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_254_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_0_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_457_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_353_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_382_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_143_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_429_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_106_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_173_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_213_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_448_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_39_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_304_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_48_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_123_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_190_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_446_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_165_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_208_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_116_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_239_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_405_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_54_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_160_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_198_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_416_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_58_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_62_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_361_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_286_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_485_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_424_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_234_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_168_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_216_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_110_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_273_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_313_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_141_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_4_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_44_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_342_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_93_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_169_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_84_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_464_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_397_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_127_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_262_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_324_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_387_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_212_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_157_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_409_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_237_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_432_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_317_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_172_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_96_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_170_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_17_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_465_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_338_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_3_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_363_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_482_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_467_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_325_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_228_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_126_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_241_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_400_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_415_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_31_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_437_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_65_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_178_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_227_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_82_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_370_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_232_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_89_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_46_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_315_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_366_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_461_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_144_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_284_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_352_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_95_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_335_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_122_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_100_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_374_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_259_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_300_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_356_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_215_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_282_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_336_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_131_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_270_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_309_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_250_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_460_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_19_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_69_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_450_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_114_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_436_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_177_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_104_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_302_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_399_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_449_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_193_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_423_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_377_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_194_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_339_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_346_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_243_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_384_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_47_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_345_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_149_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_303_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_98_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_307_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_41_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_421_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_256_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_174_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_271_mesh.off
# file_path: ../../../data/test/xyt/meshes/noise/group_10_mesh.off
