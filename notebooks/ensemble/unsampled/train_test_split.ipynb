# %% [markdown]
# # Prepare Data for Train-Test

# %%
def housekeeping(files):
    """
    Checks and removes unwanted files or folders
    1. .ipynb_checkpoints/
    2. .DS_Store
    3. train/
    4. test/
    """
    
    if ".ipynb_checkpoints" in files:
        print("Removing .ipynb_checkpoints...")
        shutil.rmtree(path + ".ipynb_checkpoints")
    else:
        print("No action taken")
        
    if ".DS_Store" in files:
        os.remove(path + ".DS_Store")
    else:
        print("No action taken")
        
    if 'train' or 'test' in files:
        return
#         try:
#             shutil.rmtree(path + 'train')
#         except OSError as e:
#             print ("Note: %s - %s." % (e.filename, e.strerror))
#         try:
#             shutil.rmtree(path + 'test')
#         except OSError as e:
#             print ("Note: %s - %s." % (e.filename, e.strerror))
    
    return


def randomize_files(files):
    """
    Shuffles files in a random order
    """
    return shuffle(files)


def prepare_split(files):
    """
    Identifies the ratios for files to be split into
    
    **Note**
    Current setting is for 80-20
    """
    eighty = int(0.8 * len(files))
    twenty = int(len(files) - eighty)
    files = np.array(files)
    
    return eighty, twenty, files


def generate_ids(eighty, twenty):
    """
    Assigns 1 to 80% of the files and 0 to 20% of the files
    """
    idx = np.hstack((np.ones(eighty),
                     np.zeros(twenty)))
    return idx


def train_test_split(files, idx):
    """
    Files tagged as 1 are categorised as training files
    Files tagged as 0 are categorised as test files
    """
    train = files[idx == 1]
    test = files[idx == 0]
    print("TRAIN SET: {0}".format(train))
    print("TEST SET: {0}".format(test))
    return train, test


def save_mixed_files():
    """
    Saves all mixed groups in the respective train and test folders
    """
    dir_mixed_paths = [PATH_MIXED + "train/", PATH_MIXED + "test/"]

    for paths, category in zip(dir_mixed_paths, categories):
        if not os.path.exists(paths):
            os.makedirs(paths)
        
        if os.path.exists(paths):
            for file in category:
                file_path = PATH_MIXED + file
                print(f'file_path: {file_path}')
                shutil.move(file_path, paths)
                
                
def save_noise_files():
    """
    Saves all noise files in its respective train and test folders
    """
    dir_noise_paths = [PATH_NOISE + "train/", PATH_NOISE + "test/"]

    for paths, category in zip(dir_noise_paths, categories):
        if not os.path.exists(paths):
            os.makedirs(paths)

        if os.path.exists(paths):
            for noise_file in category:
                file_path = PATH_NOISE + noise_file
                print(f'file_path: {file_path}')
                shutil.move(file_path, paths)

# %%
import pandas as pd
import numpy as np
import os
import random
from random import shuffle
import shutil

PATH_MIXED = "../../../data/unsampled/xzt/meshes/mixed/"
PATH_NOISE = "../../../data/unsampled/xzt/meshes/noise/"

dir_paths = [PATH_MIXED, PATH_NOISE]
save_types = [save_mixed_files, save_noise_files]


for path, types in zip(dir_paths, save_types):
    print("Working on {}".format(path))
    
    # Cleanup unwanted files/folders    
    files = os.listdir(path)
    
    housekeeping(files)
    
# #     # First: Randomize data 
    randomize_files(files)
    print(files)
    
# #     # Calculate Split
    eighty, twenty, files = prepare_split(files)

# #     # Generate 1s and 0s as IDs
    idx = generate_ids(eighty, twenty)

# #     # Split data 
    train, test = train_test_split(files, idx) 
    categories = [train, test]
    types()
# Out:
# Working on ../../../data/unsampled/xzt/meshes/mixed/
# No action taken
# No action taken
# ['group_1273_mesh.off', 'group_4717_mesh.off', 'group_3953_mesh.off', 'group_5116_mesh.off', 'group_4034_mesh.off', 'group_988_mesh.off', 'group_797_mesh.off', 'group_1357_mesh.off', 'group_5795_mesh.off', 'group_4679_mesh.off', 'group_5270_mesh.off', 'group_3778_mesh.off', 'group_6134_mesh.off', 'group_6534_mesh.off', 'group_615_mesh.off', 'group_4646_mesh.off', 'group_5281_mesh.off', 'group_5725_mesh.off', 'group_2362_mesh.off', 'group_1887_mesh.off', 'group_2231_mesh.off', 'group_1454_mesh.off', 'group_491_mesh.off', 'group_6493_mesh.off', 'group_5857_mesh.off', 'group_6109_mesh.off', 'group_5030_mesh.off', 'group_5032_mesh.off', 'group_5151_mesh.off', 'group_4336_mesh.off', 'group_5931_mesh.off', 'group_1276_mesh.off', 'group_639_mesh.off', 'group_6084_mesh.off', 'group_3924_mesh.off', 'group_3170_mesh.off', 'group_1650_mesh.off', 'group_6553_mesh.off', 'group_6038_mesh.off', 'group_231_mesh.off', 'group_3514_mesh.off', 'group_1038_mesh.off', 'group_1496_mesh.off', 'group_4515_mesh.off', 'group_3483_mesh.off', 'group_2338_mesh.off', 'group_584_mesh.off', 'group_4301_mesh.off', 'group_3490_mesh.off', 'group_5312_mesh.off', 'group_5799_mesh.off', 'group_3094_mesh.off', 'group_4741_mesh.off', 'group_5295_mesh.off', 'group_2367_mesh.off', 'group_4735_mesh.off', 'group_691_mesh.off', 'group_1194_mesh.off', 'group_3252_mesh.off', 'group_4347_mesh.off', 'group_4783_mesh.off', 'group_4793_mesh.off', 'group_2024_mesh.off', 'group_3923_mesh.off', 'group_375_mesh.off', 'group_4620_mesh.off', 'group_1732_mesh.off', 'group_3001_mesh.off', 'group_3398_mesh.off', 'group_607_mesh.off', 'group_5659_mesh.off', 'group_6337_mesh.off', 'group_2731_mesh.off', 'group_5211_mesh.off', 'group_2795_mesh.off', 'group_4417_mesh.off', 'group_2759_mesh.off', 'group_3025_mesh.off', 'group_3967_mesh.off', 'group_5866_mesh.off', 'group_5823_mesh.off', 'group_2021_mesh.off', 'group_1209_mesh.off', 'group_2323_mesh.off', 'group_6378_mesh.off', 'group_4854_mesh.off', 'group_4215_mesh.off', 'group_1869_mesh.off', 'group_4080_mesh.off', 'group_3063_mesh.off', 'group_4943_mesh.off', 'group_3611_mesh.off', 'group_1599_mesh.off', 'group_2389_mesh.off', 'group_530_mesh.off', 'group_1618_mesh.off', 'group_2711_mesh.off', 'group_3845_mesh.off', 'group_5000_mesh.off', 'group_5621_mesh.off', 'group_1141_mesh.off', 'group_554_mesh.off', 'group_2654_mesh.off', 'group_3287_mesh.off', 'group_1163_mesh.off', 'group_1344_mesh.off', 'group_4327_mesh.off', 'group_1214_mesh.off', 'group_716_mesh.off', 'group_3700_mesh.off', 'group_1671_mesh.off', 'group_5747_mesh.off', 'group_2567_mesh.off', 'group_477_mesh.off', 'group_3740_mesh.off', 'group_5010_mesh.off', 'group_394_mesh.off', 'group_5133_mesh.off', 'group_6530_mesh.off', 'group_6567_mesh.off', 'group_4023_mesh.off', 'group_4532_mesh.off', 'group_1813_mesh.off', 'group_1446_mesh.off', 'group_3727_mesh.off', 'group_32_mesh.off', 'group_1516_mesh.off', 'group_1172_mesh.off', 'group_857_mesh.off', 'group_5114_mesh.off', 'group_6564_mesh.off', 'group_3084_mesh.off', 'group_1825_mesh.off', 'group_5976_mesh.off', 'group_1653_mesh.off', 'group_1275_mesh.off', 'group_1488_mesh.off', 'group_4104_mesh.off', 'group_1836_mesh.off', 'group_6221_mesh.off', 'group_1658_mesh.off', 'group_469_mesh.off', 'group_997_mesh.off', 'group_3310_mesh.off', 'group_809_mesh.off', 'group_4460_mesh.off', 'group_4565_mesh.off', 'group_5886_mesh.off', 'group_2821_mesh.off', 'group_4227_mesh.off', 'group_55_mesh.off', 'group_355_mesh.off', 'group_5812_mesh.off', 'group_3670_mesh.off', 'group_1918_mesh.off', 'group_2293_mesh.off', 'group_2374_mesh.off', 'group_3570_mesh.off', 'group_4958_mesh.off', 'group_787_mesh.off', 'group_1764_mesh.off', 'group_5883_mesh.off', 'group_4282_mesh.off', 'group_3212_mesh.off', 'group_440_mesh.off', 'group_979_mesh.off', 'group_6314_mesh.off', 'group_6495_mesh.off', 'group_50_mesh.off', 'group_2447_mesh.off', 'group_1973_mesh.off', 'group_6542_mesh.off', 'group_4243_mesh.off', 'group_1184_mesh.off', 'group_810_mesh.off', 'gro ...
# TRAIN SET: ['group_1273_mesh.off' 'group_4717_mesh.off' 'group_3953_mesh.off'
#  'group_5116_mesh.off' 'group_4034_mesh.off' 'group_988_mesh.off'
#  'group_797_mesh.off' 'group_1357_mesh.off' 'group_5795_mesh.off'
#  'group_4679_mesh.off' 'group_5270_mesh.off' 'group_3778_mesh.off'
#  'group_6134_mesh.off' 'group_6534_mesh.off' 'group_615_mesh.off'
#  'group_4646_mesh.off' 'group_5281_mesh.off' 'group_5725_mesh.off'
#  'group_2362_mesh.off' 'group_1887_mesh.off' 'group_2231_mesh.off'
#  'group_1454_mesh.off' 'group_491_mesh.off' 'group_6493_mesh.off'
#  'group_5857_mesh.off' 'group_6109_mesh.off' 'group_5030_mesh.off'
#  'group_5032_mesh.off' 'group_5151_mesh.off' 'group_4336_mesh.off'
#  'group_5931_mesh.off' 'group_1276_mesh.off' 'group_639_mesh.off'
#  'group_6084_mesh.off' 'group_3924_mesh.off' 'group_3170_mesh.off'
#  'group_1650_mesh.off' 'group_6553_mesh.off' 'group_6038_mesh.off'
#  'group_231_mesh.off' 'group_3514_mesh.off' 'group_1038_mesh.off'
#  'group_1496_mesh.off' 'group_4515_mesh.off' 'group_3483_mesh.off'
#  'group_2338_mesh.off' 'group_584_mesh.off' 'group_4301_mesh.off'
#  'group_3490_mesh.off' 'group_5312_mesh.off' 'group_5799_mesh.off'
#  'group_3094_mesh.off' 'group_4741_mesh.off' 'group_5295_mesh.off'
#  'group_2367_mesh.off' 'group_4735_mesh.off' 'group_691_mesh.off'
#  'group_1194_mesh.off' 'group_3252_mesh.off' 'group_4347_mesh.off'
#  'group_4783_mesh.off' 'group_4793_mesh.off' 'group_2024_mesh.off'
#  'group_3923_mesh.off' 'group_375_mesh.off' 'group_4620_mesh.off'
#  'group_1732_mesh.off' 'group_3001_mesh.off' 'group_3398_mesh.off'
#  'group_607_mesh.off' 'group_5659_mesh.off' 'group_6337_mesh.off'
#  'group_2731_mesh.off' 'group_5211_mesh.off' 'group_2795_mesh.off'
#  'group_4417_mesh.off' 'group_2759_mesh.off' 'group_3025_mesh.off'
#  'group_3967_mesh.off' 'group_5866_mesh.off' 'group_5823_mesh.off'
#  'group_2021_mesh.off' 'group_1209_mesh.off' 'group_2323_mesh.off'
#  'group_6378_mesh.off' 'group_4854_mesh.off' 'group_4215_mesh.off'
#  'group_1869_mesh.off' 'group_4080_mesh.off' 'group_3063_mesh.off'
#  'group_4943_mesh.off' 'group_3611_mesh.off' 'group_1599_mesh.off'
#  'group_2389_mesh.off' 'group_530_mesh.off' 'group_1618_mesh.off'
#  'group_2711_mesh.off' 'group_3845_mesh.off' 'group_5000_mesh.off'
#  'group_5621_mesh.off' 'group_1141_mesh.off' 'group_554_mesh.off'
#  'group_2654_mesh.off' 'group_3287_mesh.off' 'group_1163_mesh.off'
#  'group_1344_mesh.off' 'group_4327_mesh.off' 'group_1214_mesh.off'
#  'group_716_mesh.off' 'group_3700_mesh.off' 'group_1671_mesh.off'
#  'group_5747_mesh.off' 'group_2567_mesh.off' 'group_477_mesh.off'
#  'group_3740_mesh.off' 'group_5010_mesh.off' 'group_394_mesh.off'
#  'group_5133_mesh.off' 'group_6530_mesh.off' 'group_6567_mesh.off'
#  'group_4023_mesh.off' 'group_4532_mesh.off' 'group_1813_mesh.off'
#  'group_1446_mesh.off' 'group_3727_mesh.off' 'group_32_mesh.off'
#  'group_1516_mesh.off' 'group_1172_mesh.off' 'group_857_mesh.off'
#  'group_5114_mesh.off' 'group_6564_mesh.off' 'group_3084_mesh.off'
#  'group_1825_mesh.off' 'group_5976_mesh.off' 'group_1653_mesh.off'
#  'group_1275_mesh.off' 'group_1488_mesh.off' 'group_4104_mesh.off'
#  'group_1836_mesh.off' 'group_6221_mesh.off' 'group_1658_mesh.off'
#  'group_469_mesh.off' 'group_997_mesh.off' 'group_3310_mesh.off'
#  'group_809_mesh.off' 'group_4460_mesh.off' 'group_4565_mesh.off'
#  'group_5886_mesh.off' 'group_2821_mesh.off' 'group_4227_mesh.off'
#  'group_55_mesh.off' 'group_355_mesh.off' 'group_5812_mesh.off'
#  'group_3670_mesh.off' 'group_1918_mesh.off' 'group_2293_mesh.off'
mesh.off
# file_path: ../../../data/unsampled/xzt/meshes/mixed/group_1637_mesh.off
# Working on ../../../data/unsampled/xzt/meshes/noise/
# No action taken
# No action taken
# ['group_5718_mesh.off', 'group_1016_mesh.off', 'group_3215_mesh.off', 'group_4796_mesh.off', 'group_2719_mesh.off', 'group_2093_mesh.off', 'group_3219_mesh.off', 'group_3492_mesh.off', 'group_6436_mesh.off', 'group_1667_mesh.off', 'group_4848_mesh.off', 'group_3416_mesh.off', 'group_208_mesh.off', 'group_4571_mesh.off', 'group_3792_mesh.off', 'group_5412_mesh.off', 'group_990_mesh.off', 'group_4267_mesh.off', 'group_758_mesh.off', 'group_3253_mesh.off', 'group_210_mesh.off', 'group_5190_mesh.off', 'group_630_mesh.off', 'group_1151_mesh.off', 'group_3352_mesh.off', 'group_4060_mesh.off', 'group_4483_mesh.off', 'group_576_mesh.off', 'group_4463_mesh.off', 'group_4199_mesh.off', 'group_4870_mesh.off', 'group_5308_mesh.off', 'group_2932_mesh.off', 'group_6181_mesh.off', 'group_762_mesh.off', 'group_4775_mesh.off', 'group_3594_mesh.off', 'group_4019_mesh.off', 'group_5922_mesh.off', 'group_3340_mesh.off', 'group_3222_mesh.off', 'group_1567_mesh.off', 'group_416_mesh.off', 'group_601_mesh.off', 'group_4391_mesh.off', 'group_1955_mesh.off', 'group_5097_mesh.off', 'group_3042_mesh.off', 'group_5510_mesh.off', 'group_6177_mesh.off', 'group_3941_mesh.off', 'group_5337_mesh.off', 'group_2197_mesh.off', 'group_3974_mesh.off', 'group_5103_mesh.off', 'group_6560_mesh.off', 'group_347_mesh.off', 'group_2658_mesh.off', 'group_4444_mesh.off', 'group_6555_mesh.off', 'group_6433_mesh.off', 'group_3758_mesh.off', 'group_2621_mesh.off', 'group_1374_mesh.off', 'group_4426_mesh.off', 'group_2956_mesh.off', 'group_3799_mesh.off', 'group_4647_mesh.off', 'group_134_mesh.off', 'group_1189_mesh.off', 'group_6540_mesh.off', 'group_1413_mesh.off', 'group_6630_mesh.off', 'group_4671_mesh.off', 'group_1405_mesh.off', 'group_788_mesh.off', 'group_6432_mesh.off', 'group_5977_mesh.off', 'group_2128_mesh.off', 'group_6132_mesh.off', 'group_4081_mesh.off', 'group_4640_mesh.off', 'group_3507_mesh.off', 'group_2872_mesh.off', 'group_3403_mesh.off', 'group_5991_mesh.off', 'group_6427_mesh.off', 'group_4799_mesh.off', 'group_3440_mesh.off', 'group_3763_mesh.off', 'group_5067_mesh.off', 'group_2869_mesh.off', 'group_3968_mesh.off', 'group_4477_mesh.off', 'group_1846_mesh.off', 'group_2272_mesh.off', 'group_1729_mesh.off', 'group_5605_mesh.off', 'group_1101_mesh.off', 'group_5038_mesh.off', 'group_1108_mesh.off', 'group_2751_mesh.off', 'group_5006_mesh.off', 'group_6139_mesh.off', 'group_6241_mesh.off', 'group_2414_mesh.off', 'group_2587_mesh.off', 'group_3180_mesh.off', 'group_6048_mesh.off', 'group_4591_mesh.off', 'group_2834_mesh.off', 'group_3815_mesh.off', 'group_449_mesh.off', 'group_4969_mesh.off', 'group_3960_mesh.off', 'group_432_mesh.off', 'group_4179_mesh.off', 'group_1531_mesh.off', 'group_5941_mesh.off', 'group_914_mesh.off', 'group_4274_mesh.off', 'group_5491_mesh.off', 'group_2934_mesh.off', 'group_5701_mesh.off', 'group_190_mesh.off', 'group_2385_mesh.off', 'group_6117_mesh.off', 'group_1202_mesh.off', 'group_3152_mesh.off', 'group_4900_mesh.off', 'group_5182_mesh.off', 'group_6589_mesh.off', 'group_6396_mesh.off', 'group_5434_mesh.off', 'group_669_mesh.off', 'group_1325_mesh.off', 'group_5678_mesh.off', 'group_583_mesh.off', 'group_1204_mesh.off', 'group_3168_mesh.off', 'group_5222_mesh.off', 'group_4032_mesh.off', 'group_1346_mesh.off', 'group_5009_mesh.off', 'group_0_mesh.off', 'group_374_mesh.off', 'group_5982_mesh.off', 'group_3985_mesh.off', 'group_2527_mesh.off', 'group_5550_mesh.off', 'group_1681_mesh.off', 'group_3925_mesh.off', 'group_2557_mesh.off', 'group_648_mesh.off', 'group_1391_mesh.off', 'group_1583_mesh.off', 'group_1129_mesh.off', 'group_3569_mesh.off', 'group_4695_mesh.off', 'group_4328_mesh.off', 'group_3943_mesh.off', 'group_3704_mesh.off', 'group_4590_mesh.off', 'group_5578_mesh.off', 'group_903_mesh.off', 'group_1481_mesh.off', 'group_3123_mesh.off', 'group_3060_mesh.off', 'group_5840_mesh.off', 'group_3355_mesh.off', 'group_4897_mesh.off', 'group_3189_mesh.off', 'group_1620_mesh.off', 'group_1055_mesh.off', 'group_5149_mesh.off' ...
# TRAIN SET: ['group_5718_mesh.off' 'group_1016_mesh.off' 'group_3215_mesh.off'
#  'group_4796_mesh.off' 'group_2719_mesh.off' 'group_2093_mesh.off'
#  'group_3219_mesh.off' 'group_3492_mesh.off' 'group_6436_mesh.off'
#  'group_1667_mesh.off' 'group_4848_mesh.off' 'group_3416_mesh.off'
#  'group_208_mesh.off' 'group_4571_mesh.off' 'group_3792_mesh.off'
#  'group_5412_mesh.off' 'group_990_mesh.off' 'group_4267_mesh.off'
#  'group_758_mesh.off' 'group_3253_mesh.off' 'group_210_mesh.off'
#  'group_5190_mesh.off' 'group_630_mesh.off' 'group_1151_mesh.off'
#  'group_3352_mesh.off' 'group_4060_mesh.off' 'group_4483_mesh.off'
#  'group_576_mesh.off' 'group_4463_mesh.off' 'group_4199_mesh.off'
#  'group_4870_mesh.off' 'group_5308_mesh.off' 'group_2932_mesh.off'
#  'group_6181_mesh.off' 'group_762_mesh.off' 'group_4775_mesh.off'
#  'group_3594_mesh.off' 'group_4019_mesh.off' 'group_5922_mesh.off'
#  'group_3340_mesh.off' 'group_3222_mesh.off' 'group_1567_mesh.off'
#  'group_416_mesh.off' 'group_601_mesh.off' 'group_4391_mesh.off'
#  'group_1955_mesh.off' 'group_5097_mesh.off' 'group_3042_mesh.off'
#  'group_5510_mesh.off' 'group_6177_mesh.off' 'group_3941_mesh.off'
#  'group_5337_mesh.off' 'group_2197_mesh.off' 'group_3974_mesh.off'
#  'group_5103_mesh.off' 'group_6560_mesh.off' 'group_347_mesh.off'
#  'group_2658_mesh.off' 'group_4444_mesh.off' 'group_6555_mesh.off'
#  'group_6433_mesh.off' 'group_3758_mesh.off' 'group_2621_mesh.off'
#  'group_1374_mesh.off' 'group_4426_mesh.off' 'group_2956_mesh.off'
#  'group_3799_mesh.off' 'group_4647_mesh.off' 'group_134_mesh.off'
#  'group_1189_mesh.off' 'group_6540_mesh.off' 'group_1413_mesh.off'
#  'group_6630_mesh.off' 'group_4671_mesh.off' 'group_1405_mesh.off'
#  'group_788_mesh.off' 'group_6432_mesh.off' 'group_5977_mesh.off'
#  'group_2128_mesh.off' 'group_6132_mesh.off' 'group_4081_mesh.off'
#  'group_4640_mesh.off' 'group_3507_mesh.off' 'group_2872_mesh.off'
#  'group_3403_mesh.off' 'group_5991_mesh.off' 'group_6427_mesh.off'
#  'group_4799_mesh.off' 'group_3440_mesh.off' 'group_3763_mesh.off'
#  'group_5067_mesh.off' 'group_2869_mesh.off' 'group_3968_mesh.off'
#  'group_4477_mesh.off' 'group_1846_mesh.off' 'group_2272_mesh.off'
#  'group_1729_mesh.off' 'group_5605_mesh.off' 'group_1101_mesh.off'
#  'group_5038_mesh.off' 'group_1108_mesh.off' 'group_2751_mesh.off'
#  'group_5006_mesh.off' 'group_6139_mesh.off' 'group_6241_mesh.off'
#  'group_2414_mesh.off' 'group_2587_mesh.off' 'group_3180_mesh.off'
#  'group_6048_mesh.off' 'group_4591_mesh.off' 'group_2834_mesh.off'
#  'group_3815_mesh.off' 'group_449_mesh.off' 'group_4969_mesh.off'
#  'group_3960_mesh.off' 'group_432_mesh.off' 'group_4179_mesh.off'
#  'group_1531_mesh.off' 'group_5941_mesh.off' 'group_914_mesh.off'
#  'group_4274_mesh.off' 'group_5491_mesh.off' 'group_2934_mesh.off'
#  'group_5701_mesh.off' 'group_190_mesh.off' 'group_2385_mesh.off'
#  'group_6117_mesh.off' 'group_1202_mesh.off' 'group_3152_mesh.off'
#  'group_4900_mesh.off' 'group_5182_mesh.off' 'group_6589_mesh.off'
#  'group_6396_mesh.off' 'group_5434_mesh.off' 'group_669_mesh.off'
#  'group_1325_mesh.off' 'group_5678_mesh.off' 'group_583_mesh.off'
#  'group_1204_mesh.off' 'group_3168_mesh.off' 'group_5222_mesh.off'
#  'group_4032_mesh.off' 'group_1346_mesh.off' 'group_5009_mesh.off'
#  'group_0_mesh.off' 'group_374_mesh.off' 'group_5982_mesh.off'
#  'group_3985_mesh.off' 'group_2527_mesh.off' 'group_5550_mesh.off'
#  'group_1681_mesh.off' 'group_3925_mesh.off' 'group_2557_mesh.off'
#  'group_648_mesh.off' 'group_1391_mesh.off' 'group_1583_mesh.off'
