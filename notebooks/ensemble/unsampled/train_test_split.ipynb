# %% [markdown]
# # Prepare Data for Train-Test

# %%
def housekeeping(files):
    """
    Checks and removes unwanted files or folders
    1. .ipynb_checkpoints/
    2. .DS_Store
    3. train/
    4. test/
    """
    
    if ".ipynb_checkpoints" in files:
        print("Removing .ipynb_checkpoints...")
        shutil.rmtree(path + ".ipynb_checkpoints")
    else:
        print("No action taken")
        
    if ".DS_Store" in files:
        os.remove(path + ".DS_Store")
    else:
        print("No action taken")
        
    if 'train' or 'test' in files:
        return
#         try:
#             shutil.rmtree(path + 'train')
#         except OSError as e:
#             print ("Note: %s - %s." % (e.filename, e.strerror))
#         try:
#             shutil.rmtree(path + 'test')
#         except OSError as e:
#             print ("Note: %s - %s." % (e.filename, e.strerror))
    
    return


def randomize_files(files):
    """
    Shuffles files in a random order
    """
    return shuffle(files)


def prepare_split(files):
    """
    Identifies the ratios for files to be split into
    
    **Note**
    Current setting is for 80-20
    """
    eighty = int(0.8 * len(files))
    twenty = int(len(files) - eighty)
    files = np.array(files)
    
    return eighty, twenty, files


def generate_ids(eighty, twenty):
    """
    Assigns 1 to 80% of the files and 0 to 20% of the files
    """
    idx = np.hstack((np.ones(eighty),
                     np.zeros(twenty)))
    return idx


def train_test_split(files, idx):
    """
    Files tagged as 1 are categorised as training files
    Files tagged as 0 are categorised as test files
    """
    train = files[idx == 1]
    test = files[idx == 0]
    print("TRAIN SET: {0}".format(train))
    print("TEST SET: {0}".format(test))
    return train, test


def save_mixed_files():
    """
    Saves all mixed groups in the respective train and test folders
    """
    dir_mixed_paths = [PATH_MIXED + "train/", PATH_MIXED + "test/"]

    for paths, category in zip(dir_mixed_paths, categories):
        if not os.path.exists(paths):
            os.makedirs(paths)
        
        if os.path.exists(paths):
            for file in category:
                file_path = PATH_MIXED + file
                print(f'file_path: {file_path}')
                shutil.move(file_path, paths)
                
                
def save_noise_files():
    """
    Saves all noise files in its respective train and test folders
    """
    dir_noise_paths = [PATH_NOISE + "train/", PATH_NOISE + "test/"]

    for paths, category in zip(dir_noise_paths, categories):
        if not os.path.exists(paths):
            os.makedirs(paths)

        if os.path.exists(paths):
            for noise_file in category:
                file_path = PATH_NOISE + noise_file
                print(f'file_path: {file_path}')
                shutil.move(file_path, paths)

# %%
import pandas as pd
import numpy as np
import os
import random
from random import shuffle
import shutil

PATH_MIXED = "../../../data/unsampled/yzt/meshes/mixed/"
PATH_NOISE = "../../../data/unsampled/yzt/meshes/noise/"

dir_paths = [PATH_MIXED, PATH_NOISE]
save_types = [save_mixed_files, save_noise_files]


for path, types in zip(dir_paths, save_types):
    print("Working on {}".format(path))
    
    # Cleanup unwanted files/folders    
    files = os.listdir(path)
    
    housekeeping(files)
    
#     # First: Randomize data 
#     housekeeping(files)
    randomize_files(files)
    
#     # Calculate Split
    eighty, twenty, files = prepare_split(files)

#     # Generate 1s and 0s as IDs
    idx = generate_ids(eighty, twenty)

#     # Split data 
    train, test = train_test_split(files, idx) 
#     housekeeping(files)
    categories = [train, test]
    types()
# Out:
# Working on ../../../data/unsampled/yzt/meshes/mixed/
# No action taken
# No action taken
# TRAIN SET: ['train']
# TEST SET: ['test']
# file_path: ../../../data/unsampled/yzt/meshes/mixed/train
# file_path: ../../../data/unsampled/yzt/meshes/mixed/test
# Working on ../../../data/unsampled/yzt/meshes/noise/
# No action taken
# No action taken
# TRAIN SET: ['group_3215_mesh.off' 'group_4199_mesh.off' 'group_5578_mesh.off'
#  'group_3416_mesh.off' 'group_1151_mesh.off' 'group_2557_mesh.off'
#  'group_2128_mesh.off' 'group_5941_mesh.off' 'group_2751_mesh.off'
#  'group_4328_mesh.off' 'group_3042_mesh.off' 'group_3507_mesh.off'
#  'group_5222_mesh.off' 'group_1016_mesh.off' 'group_5648_mesh.off'
#  'group_3569_mesh.off' 'group_5067_mesh.off' 'group_301_mesh.off'
#  'group_374_mesh.off' 'group_5308_mesh.off' 'group_5182_mesh.off'
#  'group_5991_mesh.off' 'group_4969_mesh.off' 'group_4615_mesh.off'
#  'group_4019_mesh.off' 'group_1639_mesh.off' 'group_5103_mesh.off'
#  'group_6241_mesh.off' 'group_6436_mesh.off' 'group_474_mesh.off'
#  'group_3943_mesh.off' 'group_532_mesh.off' 'group_5905_mesh.off'
#  'group_3152_mesh.off' 'group_5701_mesh.off' 'group_3189_mesh.off'
#  'group_1108_mesh.off' 'group_2956_mesh.off' 'group_1055_mesh.off'
#  'group_134_mesh.off' 'group_3222_mesh.off' 'group_1129_mesh.off'
#  'group_1955_mesh.off' 'group_1729_mesh.off' 'group_5434_mesh.off'
#  'group_5149_mesh.off' 'group_6117_mesh.off' 'group_2875_mesh.off'
#  'group_4444_mesh.off' 'group_909_mesh.off' 'group_2527_mesh.off'
#  'group_1101_mesh.off' 'group_903_mesh.off' 'group_999_mesh.off'
#  'group_3799_mesh.off' 'group_2272_mesh.off' 'group_2414_mesh.off'
#  'group_5922_mesh.off' 'group_3168_mesh.off' 'group_6630_mesh.off'
#  'group_416_mesh.off' 'group_2934_mesh.off' 'group_4989_mesh.off'
#  'group_4775_mesh.off' 'group_4463_mesh.off' 'group_669_mesh.off'
#  'group_583_mesh.off' 'group_4483_mesh.off' 'group_3704_mesh.off'
#  'group_1304_mesh.off' 'group_6333_mesh.off' 'group_3355_mesh.off' 'train'
#  'group_5510_mesh.off' 'group_437_mesh.off' 'group_1620_mesh.off'
#  'group_6432_mesh.off' 'group_4796_mesh.off' 'group_5491_mesh.off'
#  'group_686_mesh.off' 'group_2719_mesh.off' 'group_1846_mesh.off'
#  'group_1531_mesh.off' 'group_6555_mesh.off' 'group_5982_mesh.off'
#  'group_6589_mesh.off' 'group_2932_mesh.off' 'group_347_mesh.off'
#  'group_3985_mesh.off' 'group_3219_mesh.off' 'group_3758_mesh.off'
#  'group_5840_mesh.off' 'group_2533_mesh.off']
# TEST SET: ['group_3403_mesh.off' 'group_3352_mesh.off' 'group_2385_mesh.off'
#  'group_3487_mesh.off' 'group_990_mesh.off' 'group_3340_mesh.off'
#  'group_4060_mesh.off' 'group_4081_mesh.off' 'group_6396_mesh.off'
#  'group_630_mesh.off' 'group_1567_mesh.off' 'group_1189_mesh.off'
#  'group_3925_mesh.off' 'group_1204_mesh.off' 'group_4477_mesh.off'
#  'group_2587_mesh.off' 'group_6132_mesh.off' 'group_5678_mesh.off'
#  'group_2872_mesh.off' 'group_1405_mesh.off' 'group_1333_mesh.off'
#  'group_1391_mesh.off' 'group_0_mesh.off' 'group_3609_mesh.off']
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_3215_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_4199_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_5578_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_3416_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_1151_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_2557_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_2128_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_5941_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_2751_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_4328_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_3042_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_3507_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_5222_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_1016_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_5648_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_3569_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_5067_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_301_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_374_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_5308_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_5182_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_5991_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_4969_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_4615_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_4019_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_1639_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_5103_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_6241_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_6436_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_474_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_3943_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_532_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_5905_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_3152_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_5701_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_3189_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_1108_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_2956_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_1055_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_134_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_3222_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_1129_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_1955_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_1729_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_5434_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_5149_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_6117_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_2875_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_4444_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_909_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_2527_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_1101_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_903_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_999_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_3799_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_2272_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_2414_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_5922_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_3168_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_6630_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_416_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_2934_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_4989_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_4775_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_4463_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_669_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_583_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_4483_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_3704_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_1304_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_6333_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_3355_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/train
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_5510_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_437_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_1620_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_6432_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_4796_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_5491_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_686_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_2719_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_1846_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_1531_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_6555_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_5982_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_6589_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_2932_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_347_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_3985_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_3219_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_3758_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_5840_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_2533_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_3403_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_3352_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_2385_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_3487_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_990_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_3340_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_4060_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_4081_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_6396_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_630_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_1567_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_1189_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_3925_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_1204_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_4477_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_2587_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_6132_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_5678_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_2872_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_1405_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_1333_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_1391_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_0_mesh.off
# file_path: ../../../data/unsampled/yzt/meshes/noise/group_3609_mesh.off
