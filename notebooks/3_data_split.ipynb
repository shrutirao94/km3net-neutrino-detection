# %% [markdown]
# # Prepare Data for Train-Test

# %%
def housekeeping(files):
    """
    Checks and removes unwanted files or folders
    1. .ipynb_checkpoints/
    2. train/
    3. test/
    """
    
    if ".ipynb_checkpoints" in files:
        shutil.rmtree(path + ".ipynb_checkpoints")
        
    if 'train' or 'test' in files:
        try:
            shutil.rmtree(path + 'train')
        except OSError as e:
            print ("Note: %s - %s." % (e.filename, e.strerror))
        try:
            shutil.rmtree(path + 'test')
        except OSError as e:
            print ("Note: %s - %s." % (e.filename, e.strerror))
    
    return


def randomize_files(files):
    """
    Shuffles files in a random order
    """
    return shuffle(files)


def prepare_split(files):
    """
    Identifies the ratios for files to be split into
    
    **Note**
    Current setting is for 80-20
    """
    eighty = int(0.8 * len(files))
    twenty = int(len(files) - eighty)
    files = np.array(files)
    
    return eighty, twenty, files


def generate_ids(eighty, twenty):
    """
    Assigns 1 to 80% of the files and 0 to 20% of the files
    """
    idx = np.hstack((np.ones(eighty),
                     np.zeros(twenty)))
    return idx


def train_test_split(files, idx):
    """
    Files tagged as 1 are categorised as training files
    Files tagged as 0 are categorised as test files
    """
    train = files[idx == 1]
    test = files[idx == 0]
    print("TRAIN SET: {0}".format(train))
    print("TEST SET: {0}".format(test))
    return train, test


def save_mixed_files():
    dir_mixed_paths = [PATH_MIXED + "train/", PATH_MIXED + "test/"]

    # Save MIXED data
    for paths, category in zip(dir_mixed_paths, categories):
        if not os.path.exists(paths):
            os.makedirs(paths)
        
        if os.path.exists(paths):
            for file in category:
                file_path = PATH_MIXED + file
                print(f'file_path: {file_path}')
                shutil.move(file_path, paths)
                
                
def save_noise_files():
    dir_noise_paths = [PATH_NOISE + "train/", PATH_NOISE + "test/"]

    # Save NOISE data
    for paths, category in zip(dir_noise_paths, categories):
        if not os.path.exists(paths):
            os.makedirs(paths)

        if os.path.exists(paths):
            for noise_file in category:
                file_path = PATH_NOISE + noise_file
                print(f'file_path: {file_path}')
                shutil.move(file_path, paths)

# %%
import pandas as pd
import numpy as np
import os
import random
from random import shuffle
import shutil

PATH_MIXED = "../data/points/mixed/"
PATH_NOISE = "../data/points/noise/"

dir_paths = [PATH_MIXED, PATH_NOISE]
save_types = [save_mixed_files, save_noise_files]


for path, types in zip(dir_paths, save_types):
    print("Working on {}".format(path))
    
    # Cleanup unwanted files/folders    
    files = os.listdir(path)
    housekeeping(files)
    print (files)
    
    # First: Randomize data 
    randomize_files(files)
    
    # Calculate Split
    eighty, twenty, files = prepare_split(files)

    # Generate 1s and 0s as IDs
    idx = generate_ids(eighty, twenty)

    # Split data 
    train, test = train_test_split(files, idx) 
    categories = [train, test]
    types()
# Out:
# Working on ../data/points/mixed/
# Note: ../data/points/mixed/train - No such file or directory.
# Note: ../data/points/mixed/test - No such file or directory.
# file_path: ../data/points/mixed/group_3740.xyz
# file_path: ../data/points/mixed/group_2231.xyz
# file_path: ../data/points/mixed/group_2795.xyz
# file_path: ../data/points/mixed/.DS_Store
# file_path: ../data/points/mixed/group_1869.xyz
# file_path: ../data/points/mixed/group_5883.xyz
# file_path: ../data/points/mixed/group_1172.xyz
# file_path: ../data/points/mixed/group_3611.xyz
# file_path: ../data/points/mixed/group_3923.xyz
# file_path: ../data/points/mixed/group_5114.xyz
# file_path: ../data/points/mixed/group_4417.xyz
# file_path: ../data/points/mixed/group_6221.xyz
# file_path: ../data/points/mixed/group_3398.xyz
# file_path: ../data/points/mixed/group_2185.xyz
# file_path: ../data/points/mixed/group_5823.xyz
# file_path: ../data/points/mixed/group_32.xyz
# file_path: ../data/points/mixed/group_1671.xyz
# file_path: ../data/points/mixed/group_1653.xyz
# file_path: ../data/points/mixed/group_5815.xyz
# file_path: ../data/points/mixed/group_3170.xyz
# file_path: ../data/points/mixed/group_716.xyz
# file_path: ../data/points/mixed/group_6378.xyz
# file_path: ../data/points/mixed/group_6495.xyz
# file_path: ../data/points/mixed/group_1276.xyz
# file_path: ../data/points/mixed/group_4532.xyz
# file_path: ../data/points/mixed/group_979.xyz
# file_path: ../data/points/mixed/group_1441.xyz
# file_path: ../data/points/mixed/group_4741.xyz
# file_path: ../data/points/mixed/group_1496.xyz
# file_path: ../data/points/mixed/group_4926.xyz
# file_path: ../data/points/mixed/group_1732.xyz
# file_path: ../data/points/mixed/group_355.xyz
# file_path: ../data/points/mixed/group_6134.xyz
# file_path: ../data/points/mixed/group_5312.xyz
# file_path: ../data/points/mixed/group_3924.xyz
# file_path: ../data/points/mixed/group_2821.xyz
# file_path: ../data/points/mixed/group_1918.xyz
# file_path: ../data/points/mixed/group_1887.xyz
# file_path: ../data/points/mixed/group_5725.xyz
# file_path: ../data/points/mixed/group_607.xyz
# file_path: ../data/points/mixed/group_4347.xyz
# file_path: ../data/points/mixed/group_2362.xyz
# file_path: ../data/points/mixed/group_4646.xyz
# file_path: ../data/points/mixed/group_6534.xyz
# file_path: ../data/points/mixed/group_55.xyz
# file_path: ../data/points/mixed/group_2759.xyz
# file_path: ../data/points/mixed/group_50.xyz
# file_path: ../data/points/mixed/group_5931.xyz
# file_path: ../data/points/mixed/group_857.xyz
# file_path: ../data/points/mixed/group_2517.xyz
# file_path: ../data/points/mixed/group_5030.xyz
# file_path: ../data/points/mixed/group_6530.xyz
# file_path: ../data/points/mixed/group_4336.xyz
# file_path: ../data/points/mixed/group_4023.xyz
# file_path: ../data/points/mixed/group_3063.xyz
# file_path: ../data/points/mixed/group_1599.xyz
# file_path: ../data/points/mixed/group_5234.xyz
# file_path: ../data/points/mixed/group_491.xyz
# file_path: ../data/points/mixed/group_3514.xyz
# file_path: ../data/points/mixed/group_810.xyz
# file_path: ../data/points/mixed/group_5886.xyz
# file_path: ../data/points/mixed/group_3025.xyz
# file_path: ../data/points/mixed/group_281.xyz
# file_path: ../data/points/mixed/group_5799.xyz
# file_path: ../data/points/mixed/group_797.xyz
# file_path: ../data/points/mixed/group_1273.xyz
# file_path: ../data/points/mixed/group_5116.xyz
# file_path: ../data/points/mixed/group_3084.xyz
# file_path: ../data/points/mixed/group_1813.xyz
# file_path: ../data/points/mixed/group_584.xyz
# file_path: ../data/points/mixed/group_1275.xyz
# file_path: ../data/points/mixed/group_1214.xyz
# file_path: ../data/points/mixed/group_6553.xyz
# file_path: ../data/points/mixed/group_3570.xyz
# file_path: ../data/points/mixed/group_1344.xyz
# file_path: ../data/points/mixed/group_3212.xyz
# file_path: ../data/points/mixed/group_5010.xyz
# file_path: ../data/points/mixed/group_4104.xyz
# file_path: ../data/points/mixed/group_3670.xyz
# file_path: ../data/points/mixed/group_5795.xyz
# file_path: ../data/points/mixed/group_4943.xyz
# file_path: ../data/points/mixed/group_477.xyz
# file_path: ../data/points/mixed/group_3310.xyz
# file_path: ../data/points/mixed/group_1446.xyz
# file_path: ../data/points/mixed/group_5133.xyz
# file_path: ../data/points/mixed/group_2374.xyz
# file_path: ../data/points/mixed/group_2021.xyz
# file_path: ../data/points/mixed/group_2323.xyz
# file_path: ../data/points/mixed/group_4565.xyz
# file_path: ../data/points/mixed/group_1484.xyz
# file_path: ../data/points/mixed/group_1209.xyz
# file_path: ../data/points/mixed/group_4717.xyz
# file_path: ../data/points/mixed/group_4958.xyz
# file_path: ../data/points/mixed/group_639.xyz
# file_path: ../data/points/mixed/group_1825.xyz
# file_path: ../data/points/mixed/group_6337.xyz
# file_path: ../data/points/mixed/group_1038.xyz
# file_path: ../data/points/mixed/group_941.xyz
# file_path: ../data/points/mixed/group_103.xyz
# file_path: ../data/points/mixed/group_1584.xyz
# file_path: ../data/points/mixed/group_2024.xyz
# file_path: ../data/points/mixed/group_997.xyz
# file_path: ../data/points/mixed/group_5747.xyz
# file_path: ../data/points/mixed/group_988.xyz
# file_path: ../data/points/mixed/group_1973.xyz
# file_path: ../data/points/mixed/group_440.xyz
# file_path: ../data/points/mixed/group_5215.xyz
# file_path: ../data/points/mixed/group_6493.xyz
# file_path: ../data/points/mixed/group_5151.xyz
# file_path: ../data/points/mixed/group_4227.xyz
# file_path: ../data/points/mixed/group_3700.xyz
# file_path: ../data/points/mixed/group_4301.xyz
# file_path: ../data/points/mixed/group_2389.xyz
# file_path: ../data/points/mixed/group_3094.xyz
# file_path: ../data/points/mixed/group_2731.xyz
# file_path: ../data/points/mixed/group_6084.xyz
# file_path: ../data/points/mixed/group_5976.xyz
# file_path: ../data/points/mixed/group_3483.xyz
# file_path: ../data/points/mixed/group_1650.xyz
# file_path: ../data/points/mixed/group_5281.xyz
# file_path: ../data/points/mixed/group_249.xyz
# file_path: ../data/points/mixed/group_2711.xyz
# file_path: ../data/points/mixed/group_4562.xyz
# file_path: ../data/points/mixed/group_6054.xyz
# file_path: ../data/points/mixed/group_5295.xyz
# file_path: ../data/points/mixed/group_2447.xyz
# file_path: ../data/points/mixed/group_1658.xyz
# file_path: ../data/points/mixed/group_6038.xyz
# file_path: ../data/points/mixed/group_5422.xyz
# file_path: ../data/points/mixed/group_3967.xyz
# file_path: ../data/points/mixed/group_1232.xyz
# file_path: ../data/points/mixed/group_394.xyz
# file_path: ../data/points/mixed/group_809.xyz
# file_path: ../data/points/mixed/group_5621.xyz
# file_path: ../data/points/mixed/group_1184.xyz
# file_path: ../data/points/mixed/group_5270.xyz
# file_path: ../data/points/mixed/group_3727.xyz
# file_path: ../data/points/mixed/group_2654.xyz
# file_path: ../data/points/mixed/group_787.xyz
# file_path: ../data/points/mixed/group_4034.xyz
# file_path: ../data/points/mixed/group_3845.xyz
# file_path: ../data/points/mixed/group_6542.xyz
# file_path: ../data/points/mixed/group_2098.xyz
# file_path: ../data/points/mixed/group_1764.xyz
# file_path: ../data/points/mixed/group_2211.xyz
# file_path: ../data/points/mixed/group_4783.xyz
# file_path: ../data/points/mixed/group_6314.xyz
# file_path: ../data/points/mixed/group_2338.xyz
# file_path: ../data/points/mixed/group_4460.xyz
# file_path: ../data/points/mixed/group_6470.xyz
# file_path: ../data/points/mixed/group_3490.xyz
# file_path: ../data/points/mixed/group_3001.xyz
# file_path: ../data/points/mixed/group_3778.xyz
# file_path: ../data/points/mixed/group_1194.xyz
# file_path: ../data/points/mixed/group_554.xyz
# file_path: ../data/points/mixed/group_6588.xyz
# file_path: ../data/points/mixed/group_231.xyz
# file_path: ../data/points/mixed/group_4243.xyz
# file_path: ../data/points/mixed/group_3953.xyz
# file_path: ../data/points/mixed/group_1141.xyz
# file_path: ../data/points/mixed/group_4735.xyz
# file_path: ../data/points/mixed/group_5000.xyz
# file_path: ../data/points/mixed/group_615.xyz
# file_path: ../data/points/mixed/group_4428.xyz
# file_path: ../data/points/mixed/group_3252.xyz
# file_path: ../data/points/mixed/group_4854.xyz
# file_path: ../data/points/mixed/group_4282.xyz
# file_path: ../data/points/mixed/group_1163.xyz
# file_path: ../data/points/mixed/group_1454.xyz
# file_path: ../data/points/mixed/group_5211.xyz
# file_path: ../data/points/mixed/group_4793.xyz
# file_path: ../data/points/mixed/group_2293.xyz
# file_path: ../data/points/mixed/group_1357.xyz
# file_path: ../data/points/mixed/group_5032.xyz
# file_path: ../data/points/mixed/group_5866.xyz
# file_path: ../data/points/mixed/group_4080.xyz
# file_path: ../data/points/mixed/group_6006.xyz
# file_path: ../data/points/mixed/group_6564.xyz
# file_path: ../data/points/mixed/group_4327.xyz
# file_path: ../data/points/mixed/group_2567.xyz
# file_path: ../data/points/mixed/group_4515.xyz
# file_path: ../data/points/mixed/group_5812.xyz
# file_path: ../data/points/mixed/group_469.xyz
# file_path: ../data/points/mixed/group_5857.xyz
# file_path: ../data/points/mixed/group_1516.xyz
# file_path: ../data/points/mixed/group_4679.xyz
#  'group_69.xyz']
# file_path: ../data/points/noise/group_112.xyz
# file_path: ../data/points/noise/group_143.xyz
# file_path: ../data/points/noise/group_385.xyz
# file_path: ../data/points/noise/group_251.xyz
# file_path: ../data/points/noise/group_58.xyz
# file_path: ../data/points/noise/group_449.xyz
# file_path: ../data/points/noise/group_465.xyz
# file_path: ../data/points/noise/group_461.xyz
# file_path: ../data/points/noise/group_80.xyz
# file_path: ../data/points/noise/group_173.xyz
# file_path: ../data/points/noise/group_234.xyz
# file_path: ../data/points/noise/group_189.xyz
# file_path: ../data/points/noise/group_409.xyz
# file_path: ../data/points/noise/group_424.xyz
# file_path: ../data/points/noise/group_421.xyz
# file_path: ../data/points/noise/group_109.xyz
# file_path: ../data/points/noise/group_48.xyz
# file_path: ../data/points/noise/group_216.xyz
# file_path: ../data/points/noise/group_82.xyz
# file_path: ../data/points/noise/group_157.xyz
# file_path: ../data/points/noise/group_346.xyz
# file_path: ../data/points/noise/group_258.xyz
# file_path: ../data/points/noise/group_119.xyz
# file_path: ../data/points/noise/group_165.xyz
# file_path: ../data/points/noise/group_93.xyz
# file_path: ../data/points/noise/group_168.xyz
# file_path: ../data/points/noise/group_284.xyz
# file_path: ../data/points/noise/group_383.xyz
# file_path: ../data/points/noise/group_232.xyz
# file_path: ../data/points/noise/group_31.xyz
# file_path: ../data/points/noise/group_21.xyz
# file_path: ../data/points/noise/group_313.xyz
# file_path: ../data/points/noise/group_437.xyz
# file_path: ../data/points/noise/group_256.xyz
# file_path: ../data/points/noise/group_384.xyz
# file_path: ../data/points/noise/group_365.xyz
# file_path: ../data/points/noise/group_63.xyz
# file_path: ../data/points/noise/group_151.xyz
# file_path: ../data/points/noise/group_364.xyz
# file_path: ../data/points/noise/group_407.xyz
# file_path: ../data/points/noise/group_376.xyz
# file_path: ../data/points/noise/group_89.xyz
# file_path: ../data/points/noise/group_302.xyz
# file_path: ../data/points/noise/group_347.xyz
# file_path: ../data/points/noise/group_370.xyz
# file_path: ../data/points/noise/group_315.xyz
# file_path: ../data/points/noise/group_3.xyz
# file_path: ../data/points/noise/group_227.xyz
# file_path: ../data/points/noise/group_153.xyz
# file_path: ../data/points/noise/group_100.xyz
# file_path: ../data/points/noise/group_96.xyz
# file_path: ../data/points/noise/group_95.xyz
# file_path: ../data/points/noise/group_262.xyz
# file_path: ../data/points/noise/group_155.xyz
# file_path: ../data/points/noise/group_210.xyz
# file_path: ../data/points/noise/group_479.xyz
# file_path: ../data/points/noise/group_448.xyz
# file_path: ../data/points/noise/group_237.xyz
# file_path: ../data/points/noise/group_215.xyz
# file_path: ../data/points/noise/group_123.xyz
# file_path: ../data/points/noise/group_254.xyz
# file_path: ../data/points/noise/group_300.xyz
# file_path: ../data/points/noise/group_265.xyz
# file_path: ../data/points/noise/group_373.xyz
# file_path: ../data/points/noise/group_65.xyz
# file_path: ../data/points/noise/group_4.xyz
# file_path: ../data/points/noise/group_303.xyz
# file_path: ../data/points/noise/group_10.xyz
# file_path: ../data/points/noise/group_149.xyz
# file_path: ../data/points/noise/group_377.xyz
# file_path: ../data/points/noise/group_259.xyz
# file_path: ../data/points/noise/group_325.xyz
# file_path: ../data/points/noise/group_367.xyz
# file_path: ../data/points/noise/group_456.xyz
# file_path: ../data/points/noise/group_133.xyz
# file_path: ../data/points/noise/group_208.xyz
# file_path: ../data/points/noise/.DS_Store
# file_path: ../data/points/noise/group_446.xyz
# file_path: ../data/points/noise/group_54.xyz
# file_path: ../data/points/noise/group_114.xyz
# file_path: ../data/points/noise/group_84.xyz
# file_path: ../data/points/noise/group_485.xyz
# file_path: ../data/points/noise/group_335.xyz
# file_path: ../data/points/noise/group_460.xyz
# file_path: ../data/points/noise/group_87.xyz
# file_path: ../data/points/noise/group_141.xyz
# file_path: ../data/points/noise/group_159.xyz
# file_path: ../data/points/noise/group_252.xyz
# file_path: ../data/points/noise/group_463.xyz
# file_path: ../data/points/noise/group_131.xyz
# file_path: ../data/points/noise/group_342.xyz
# file_path: ../data/points/noise/group_338.xyz
# file_path: ../data/points/noise/group_352.xyz
# file_path: ../data/points/noise/group_336.xyz
# file_path: ../data/points/noise/group_301.xyz
# file_path: ../data/points/noise/group_14.xyz
# file_path: ../data/points/noise/group_473.xyz
# file_path: ../data/points/noise/group_91.xyz
# file_path: ../data/points/noise/group_218.xyz
# file_path: ../data/points/noise/group_464.xyz
# file_path: ../data/points/noise/group_381.xyz
# file_path: ../data/points/noise/group_467.xyz
# file_path: ../data/points/noise/group_47.xyz
# file_path: ../data/points/noise/group_106.xyz
# file_path: ../data/points/noise/group_169.xyz
# file_path: ../data/points/noise/group_450.xyz
# file_path: ../data/points/noise/group_212.xyz
# file_path: ../data/points/noise/group_439.xyz
# file_path: ../data/points/noise/group_42.xyz
# file_path: ../data/points/noise/group_137.xyz
# file_path: ../data/points/noise/group_314.xyz
# file_path: ../data/points/noise/group_416.xyz
# file_path: ../data/points/noise/group_98.xyz
# file_path: ../data/points/noise/group_104.xyz
# file_path: ../data/points/noise/group_474.xyz
# file_path: ../data/points/noise/group_224.xyz
# file_path: ../data/points/noise/group_457.xyz
# file_path: ../data/points/noise/group_160.xyz
# file_path: ../data/points/noise/group_199.xyz
# file_path: ../data/points/noise/group_220.xyz
# file_path: ../data/points/noise/group_382.xyz
# file_path: ../data/points/noise/group_127.xyz
# file_path: ../data/points/noise/group_177.xyz
# file_path: ../data/points/noise/group_354.xyz
# file_path: ../data/points/noise/group_110.xyz
# file_path: ../data/points/noise/group_196.xyz
# file_path: ../data/points/noise/group_356.xyz
# file_path: ../data/points/noise/group_62.xyz
# file_path: ../data/points/noise/group_400.xyz
# file_path: ../data/points/noise/group_417.xyz
# file_path: ../data/points/noise/group_46.xyz
# file_path: ../data/points/noise/group_170.xyz
# file_path: ../data/points/noise/group_239.xyz
# file_path: ../data/points/noise/group_293.xyz
# file_path: ../data/points/noise/group_420.xyz
# file_path: ../data/points/noise/group_291.xyz
# file_path: ../data/points/noise/group_353.xyz
# file_path: ../data/points/noise/group_17.xyz
# file_path: ../data/points/noise/group_366.xyz
# file_path: ../data/points/noise/group_374.xyz
# file_path: ../data/points/noise/group_134.xyz
# file_path: ../data/points/noise/group_190.xyz
# file_path: ../data/points/noise/group_317.xyz
# file_path: ../data/points/noise/group_144.xyz
# file_path: ../data/points/noise/group_116.xyz
# file_path: ../data/points/noise/group_436.xyz
# file_path: ../data/points/noise/group_330.xyz
# file_path: ../data/points/noise/group_405.xyz
# file_path: ../data/points/noise/group_241.xyz
# file_path: ../data/points/noise/group_307.xyz
# file_path: ../data/points/noise/group_41.xyz
# file_path: ../data/points/noise/group_228.xyz
# file_path: ../data/points/noise/group_282.xyz
# file_path: ../data/points/noise/group_198.xyz
# file_path: ../data/points/noise/group_415.xyz
# file_path: ../data/points/noise/group_345.xyz
# file_path: ../data/points/noise/group_309.xyz
# file_path: ../data/points/noise/group_286.xyz
# file_path: ../data/points/noise/group_462.xyz
# file_path: ../data/points/noise/group_245.xyz
# file_path: ../data/points/noise/group_213.xyz
# file_path: ../data/points/noise/group_271.xyz
# file_path: ../data/points/noise/group_324.xyz
# file_path: ../data/points/noise/group_423.xyz
# file_path: ../data/points/noise/group_0.xyz
# file_path: ../data/points/noise/group_397.xyz
# file_path: ../data/points/noise/group_148.xyz
# file_path: ../data/points/noise/group_328.xyz
# file_path: ../data/points/noise/group_361.xyz
# file_path: ../data/points/noise/group_183.xyz
# file_path: ../data/points/noise/group_250.xyz
# file_path: ../data/points/noise/group_304.xyz
# file_path: ../data/points/noise/group_67.xyz
# file_path: ../data/points/noise/group_77.xyz
# file_path: ../data/points/noise/group_339.xyz
# file_path: ../data/points/noise/group_399.xyz
# file_path: ../data/points/noise/group_270.xyz
# file_path: ../data/points/noise/group_39.xyz
# file_path: ../data/points/noise/group_174.xyz
# file_path: ../data/points/noise/group_194.xyz
# file_path: ../data/points/noise/group_363.xyz
# file_path: ../data/points/noise/group_482.xyz
# file_path: ../data/points/noise/group_243.xyz
# file_path: ../data/points/noise/group_126.xyz
# file_path: ../data/points/noise/group_19.xyz
# file_path: ../data/points/noise/group_285.xyz
# file_path: ../data/points/noise/group_396.xyz
# file_path: ../data/points/noise/group_278.xyz
# file_path: ../data/points/noise/group_193.xyz
# file_path: ../data/points/noise/group_178.xyz
# file_path: ../data/points/noise/group_44.xyz
# file_path: ../data/points/noise/group_122.xyz
# file_path: ../data/points/noise/group_387.xyz
# file_path: ../data/points/noise/group_8.xyz
# file_path: ../data/points/noise/group_429.xyz
# file_path: ../data/points/noise/group_432.xyz
# file_path: ../data/points/noise/group_273.xyz
# file_path: ../data/points/noise/group_172.xyz
# file_path: ../data/points/noise/group_332.xyz
# file_path: ../data/points/noise/group_30.xyz
# file_path: ../data/points/noise/group_69.xyz
